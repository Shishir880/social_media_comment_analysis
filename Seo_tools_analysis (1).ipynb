# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
comment = pd.read_csv("/content/dataset.csv")
comment2 = pd.read_csv("/content/dataset2.csv")

# %%
comment2.head()
# Out:
#               Author                     Content  Depth  SubCommentsCount  \
# 0      কিউটের ডিব্বা           Envato price koto    0.0               1.0
# 1     Md Aminul Khan          Elevenlabs ache ki    0.0               1.0
# 2  Hmd Kabirul Islam  Pictory subscription Hobe?    0.0               1.0
# 3       Dilip Sarkar                 Ahref ache?    0.0               1.0
# 4       Md Yunus Ali                        ভালো    0.0               1.0
#
#                 CommentAt
# 0  11/22/2024 03:43:03 PM
# 1  12/13/2024 12:54:41 PM
# 2  12/13/2024 08:51:47 PM
# 3  12/13/2024 11:07:52 PM
# 4  12/14/2024 08:34:23 PM

# %%
if 'Depth' in comment2.columns:
  comment2 = comment2.drop('Depth', axis=1)

comment2.head()
# Out:
#               Author                     Content  SubCommentsCount  \
# 0      কিউটের ডিব্বা           Envato price koto               1.0
# 1     Md Aminul Khan          Elevenlabs ache ki               1.0
# 2  Hmd Kabirul Islam  Pictory subscription Hobe?               1.0
# 3       Dilip Sarkar                 Ahref ache?               1.0
# 4       Md Yunus Ali                        ভালো               1.0
#
#                 CommentAt
# 0  11/22/2024 03:43:03 PM
# 1  12/13/2024 12:54:41 PM
# 2  12/13/2024 08:51:47 PM
# 3  12/13/2024 11:07:52 PM
# 4  12/14/2024 08:34:23 PM

# %%
if 'ReactionsCount' in comment.columns:
  comment = comment.drop('ReactionsCount', axis=1)

comment.head()
# Out:
#                   Author                               Content  \
# 0      Md Minhajul Islam                                    কত
# 1  Kazi Siratul Mostakim  Brilliant  learning app share price?
# 2             Nehal Anas              Lightroom premium price?
# 3    Rahmot Hossain Niaz        vi envato elements price koto?
# 4           Rehdoy Hasan            wellsaid labs Ai Voice lab
#
#    SubCommentsCount               CommentAt
# 0               1.0  06/05/2024 02:52:02 PM
# 1               0.0  06/06/2024 07:39:45 PM
# 2               1.0  06/09/2024 06:40:53 PM
# 3               1.0  06/10/2024 09:53:42 AM
# 4               2.0  06/10/2024 10:03:43 AM

# %%
comment_data = pd.concat([comment, comment2], ignore_index=True)
comment_data.head()
# Out:
#                   Author                               Content  \
# 0      Md Minhajul Islam                                    কত
# 1  Kazi Siratul Mostakim  Brilliant  learning app share price?
# 2             Nehal Anas              Lightroom premium price?
# 3    Rahmot Hossain Niaz        vi envato elements price koto?
# 4           Rehdoy Hasan            wellsaid labs Ai Voice lab
#
#    SubCommentsCount               CommentAt
# 0               1.0  06/05/2024 02:52:02 PM
# 1               0.0  06/06/2024 07:39:45 PM
# 2               1.0  06/09/2024 06:40:53 PM
# 3               1.0  06/10/2024 09:53:42 AM
# 4               2.0  06/10/2024 10:03:43 AM

# %%
comment_data.shape
# Out:
# (17320, 4)

# %%
comment_data.duplicated().sum()
# Out:
# 12945

# %%
comment_data.drop_duplicates(inplace=True)

# %%
comment_data.shape
# Out:
# (4375, 4)

# %%
comment_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4375 entries, 0 to 9632
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Author            4374 non-null   object
#  1   Content           4374 non-null   object
#  2   SubCommentsCount  4374 non-null   float64
#  3   CommentAt         4374 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 170.9+ KB

# %%
comment_data.to_csv('research.csv', index=False)

# %%
# Monthly comment counts
data= comment_data
data['CommentAt'] = pd.to_datetime(data['CommentAt'], errors='coerce') # Convert to datetime
monthly_comments = data['CommentAt'].dt.to_period("M").value_counts().sort_index()
plt.figure(figsize=(12, 6))
sns.lineplot(x=monthly_comments.index.astype(str), y=monthly_comments.values, marker='o', color='orange')
plt.title('Monthly Comment Count')
plt.xlabel('Month')
plt.ylabel('Number of Comments')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-14-740aabea0fb2>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['CommentAt'] = pd.to_datetime(data['CommentAt'], errors='coerce') # Convert to datetime

# %%
# Day of the week analysis
data['DayOfWeek'] = data['CommentAt'].dt.day_name()
day_counts = data['DayOfWeek'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=day_counts.index, y=day_counts.values, palette="mako")
plt.title('Comments by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Comments')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-15-e83ee0837879>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=day_counts.index, y=day_counts.values, palette="mako")

# %%
# Hourly comment counts
data['Hour'] = data['CommentAt'].dt.hour
hour_counts = data['Hour'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
sns.barplot(x=hour_counts.index, y=hour_counts.values, palette="coolwarm")
plt.title('Comments by Hour of the Day')
plt.xlabel('Hour')
plt.ylabel('Number of Comments')
plt.xticks(range(0, 24))
plt.show()
# Out:
# <ipython-input-16-a83528e3322f>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=hour_counts.index, y=hour_counts.values, palette="coolwarm")

# %%
# Average SubCommentsCount by day and hour
hour_day_data = data.pivot_table(index=data['CommentAt'].dt.day_name(),
                                 columns=data['CommentAt'].dt.hour,
                                 values='SubCommentsCount', aggfunc='mean')
plt.figure(figsize=(12, 8))
sns.heatmap(hour_day_data, cmap="YlGnBu", annot=True, fmt=".1f", cbar=True)
plt.title('Average SubCommentsCount (Day vs Hour)')
plt.xlabel('Hour of the Day')
plt.ylabel('Day of the Week')
plt.show()

# %%
# Word count histogram
data['WordCount'] = data['Content'].apply(lambda x: len(str(x).split()))
plt.figure(figsize=(10, 6))
sns.histplot(data['WordCount'], kde=True, bins=20, color="purple")
plt.title('Distribution of Word Count in Comments')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=data['SubCommentsCount'], color="cyan")
plt.title('Boxplot of SubCommentsCount')
plt.ylabel('SubCommentsCount')
plt.show()

# %%
from collections import Counter

# Top words in Content
data['Content'] = data['Content'].fillna('').astype(str) # Fill NaN values with empty string and convert to string
words = Counter(" ".join(data['Content']).split())
top_words = pd.DataFrame(words.most_common(10), columns=['Word', 'Frequency'])

plt.figure(figsize=(10, 6))
sns.barplot(x='Frequency', y='Word', data=top_words, palette="pastel")
plt.title('Top 10 Most Frequent Words in Content')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.show()
# Out:
# <ipython-input-20-f4509bea1ca1>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Frequency', y='Word', data=top_words, palette="pastel")
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2453 (\N{BENGALI LETTER KA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2468 (\N{BENGALI LETTER TA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# টাইমস্ট্যাম্পে রূপান্তর করা (errors='coerce' ব্যবহার করলে ইনভ্যালিড এন্ট্রি NaT হবে)
comment['CommentAt'] = pd.to_datetime(comment['CommentAt'], errors='coerce')

# NaT ভ্যালু ড্রপ করা
comment = comment.dropna(subset=['CommentAt'])

# Feature extraction
comment['Year'] = comment['CommentAt'].dt.year
comment['Month'] = comment['CommentAt'].dt.month
comment['Day'] = comment['CommentAt'].dt.day
comment['DayName'] = comment['CommentAt'].dt.day_name()
comment['Hour'] = comment['CommentAt'].dt.hour
comment['Minute'] = comment['CommentAt'].dt.minute
comment['Second'] = comment['CommentAt'].dt.second
comment['AM_PM'] = comment['CommentAt'].dt.strftime('%p')

# Display the DataFrame with features
comment.head()
# Out:
# <ipython-input-21-cd82f585bf70>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   comment['CommentAt'] = pd.to_datetime(comment['CommentAt'], errors='coerce')
# <ipython-input-21-cd82f585bf70>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comment['Year'] = comment['CommentAt'].dt.year
# <ipython-input-21-cd82f585bf70>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comment['Month'] = comment['CommentAt'].dt.month
# <ipython-input-21-cd82f585bf70>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comment['Day'] = comment['CommentAt'].dt.day
# <ipython-input-21-cd82f585bf70>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comment['DayName'] = comment['CommentAt'].dt.day_name()
# <ipython-input-21-cd82f585bf70>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comment['Hour'] = comment['CommentAt'].dt.hour
# <ipython-input-21-cd82f585bf70>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comment['Minute'] = comment['CommentAt'].dt.minute
# <ipython-input-21-cd82f585bf70>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comment['Second'] = comment['CommentAt'].dt.second
# <ipython-input-21-cd82f585bf70>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comment['AM_PM'] = comment['CommentAt'].dt.strftime('%p')
#                   Author                               Content  \
# 0      Md Minhajul Islam                                    কত
# 1  Kazi Siratul Mostakim  Brilliant  learning app share price?
# 2             Nehal Anas              Lightroom premium price?
# 3    Rahmot Hossain Niaz        vi envato elements price koto?
# 4           Rehdoy Hasan            wellsaid labs Ai Voice lab
#
#    SubCommentsCount           CommentAt  Year  Month  Day    DayName  Hour  \
# 0               1.0 2024-06-05 14:52:02  2024      6    5  Wednesday    14
# 1               0.0 2024-06-06 19:39:45  2024      6    6   Thursday    19
# 2               1.0 2024-06-09 18:40:53  2024      6    9     Sunday    18
# 3               1.0 2024-06-10 09:53:42  2024      6   10     Monday     9
# 4               2.0 2024-06-10 10:03:43  2024      6   10     Monday    10
#
#    Minute  Second AM_PM
# 0      52       2    PM
# 1      39      45    PM
# 2      40      53    PM
# 3      53      42    AM
# 4       3      43    AM

# %%
comment["AM_PM"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='AM_PM'>

# %%
comment["DayName"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='DayName'>

# %%
comment['Content'] = comment['Content'].str.lower()
price_keywords = ['price', 'দাম', 'মূল্য']
price_comments = comment[comment['Content'].str.contains('|'.join(price_keywords), na=False)]
total_comments = len(comment)
price_comments_count = len(price_comments)
price_comments_percentage = (price_comments_count / total_comments) * 100
price_comments_count, total_comments, price_comments_percentage
# Out:
# (1848, 5971, 30.94958968347011)

# %%
# মোট কমেন্ট এবং মূল্য সম্পর্কিত কমেন্টের সংখ্যা
price_comments_count = len(price_comments)
total_comments = len(comment)
price_comments_percentage = (price_comments_count / total_comments) * 100

# প্লট তৈরি
labels = ['Price-related Comments', 'Other Comments']
counts = [price_comments_count, total_comments - price_comments_count]
colors = ['#ff9999','#66b3ff']

plt.figure(figsize=(8, 5))

# পাই চার্ট
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title('Percentage of Price-related Comments')
plt.axis('equal')  # সমান বৃত্তাকার রাখতে
plt.show()

# %%
# বার চার্ট তৈরি
categories = ['Price-related Comments', 'Other Comments']
counts = [price_comments_count, total_comments - price_comments_count]

plt.figure(figsize=(8, 5))
plt.bar(categories, counts, color=['#ff9999', '#66b3ff'])
plt.title('Count of Price-related vs Other Comments')
plt.xlabel('Comment Type')
plt.ylabel('Number of Comments')
plt.xticks(rotation=15)
plt.show()

# %%
# Define a list of common digital tools/products based on context
tools_keywords = [
    'lightroom', 'photoshop', 'illustrator', 'envato', 'canva', 'wellsaid labs',
    'udemy', 'coursera', 'envato elements', 'adobe', 'ai voice', 'premium', 'pro','semrush','canva pro'
]
comment['Tools_Mentioned'] = comment['Content'].apply(lambda x: [tool for tool in tools_keywords if tool in x])
tools_mentions = comment.explode('Tools_Mentioned')['Tools_Mentioned'].value_counts()
tools_mentions_dict = tools_mentions.to_dict()
tools_mentions_dict
# Out:
# {'semrush': 467,
#  'pro': 200,
#  'canva': 113,
#  'envato': 80,
#  'premium': 76,
#  'canva pro': 55,
#  'adobe': 44,
#  'coursera': 33,
#  'udemy': 29,
#  'envato elements': 18,
#  'photoshop': 9,
#  'illustrator': 3,
#  'lightroom': 1,
#  'wellsaid labs': 1,
#  'ai voice': 1}

# %%
# # Define the list of tools/products
# tools_keywords = [
#     'lightroom', 'photoshop', 'illustrator', 'envato', 'canva', 'wellsaid labs',
#     'udemy', 'coursera', 'envato elements', 'adobe', 'ai voice', 'premium', 'pro','semrush','canva pro'
# ]




tools_keywords = [
    "Sermush Unlimited", "Ubersuggest", "Moz pro", "Grammarly", "Chatgpt plus",
    "Sincodeai", "Leonardo.ai", "Midjourney", "Bypassgpt", "Stealth Writer",
    "Writehuman.ai", "Originality Ai", "Frase.Io", "Neuronwriter", "Answerthepublic",
    "Labrika", "wordtune", "Revoicer", "Imgupscaler", "Screpy", "Mangools",
    "Seocrawl", "Linguix", "Nichesss", "Closercopy", "Copymatics", "Ocoya ai",
    "Writerzen", "Renderforest", "Placeit", "Powtoon", "Vyond", "Helium10", "Flaticon",
    "Freepik Premium", "Canva Pro", "Vecteezy", "Icons8", "Similarweb", "Tome App",
    "Uizard.io", "Airbrush", "Pngtree", "Ai Video Creator", "Flexclip", "Sketch Geniusapp",
    "Steve.ai", "Creative Fabrica", "Spamzilla", "Udemy Premium", "Linkedin Learning",
    "Coursera Plus", "Masterclass", "Codeacademy", "Skillshare", "Scribd", "Epidemic Sound",
    "Keyword Revelar", "Pixlr", "Piktochart", "Ispionage", "Article Forge", "Niche Scrapper",
    "Primevideo", "Netflix", "Seobility", "Seositecheckup", "Seoptimer", "Seoscout", "Storybase",
    "Bookbolt", "Merchinformer", "Viral Launch", "Sellthetrend", "Prettymerch", "Zonguru",
    "Smartscout", "Whatsmyserp", "Salesamurai.io", "Tube Ranker", "Creaitor.ai", "Turnitin (Plagiarism)",
    "Craftly Ai", "Jenni Ai", "Localio.ai", "Rytr.me", "Copy Ai", "Jasper Ai", "Quillbot",
    "Quetext", "Keywordtool.io", "Spyfu", "Buzzsumo", "Deepl Pro", "Article Builder", "Hashtagsforlikes",
    "Woorank", "Indexification", "Junglescout", "Buzzstream", "Picmonkey", "Fotojet", "Vista",
    "Writersonic", "Serpstat", "Unbounce", "Designbeast", "Picsart", "Ai Image", "Snackeet",
    "Dream.ai", "Grothbarseo", "Designs.ai", "Doodly", "Toonly", "Toons.ai", "Invideo", "Vidiq Pro",
    "Lovo.ai", "Topicmojo", "Play.ht", "Videoscribe", "Robinize Ai", "Peppercontent.io", "Crazyegg",
    "Brand Overflow", "B2b Leadgen", "Hoichoi.tv", "Chorki", "Ipvanish Premium", "Storyblocks",
    "Envato Elements", "Motion Arry", "Wordhero", "Katteb ai", "Writeseed", "Writecream",
    "Plugintheme.net", "Gplrock", "Lovepik", "Pikbest", "Backlink Repository", "Spinrewriter",
    "Iconscout", "Lumen5", "Nando.ai", "Ai Seo", "Word.ai", "Adspy", "500px Downloader",
    "Alamy Downloader", "Eyeem Downloader", "Favepng Downloader", "Artlist Downloader",
    "Shutterstock Downloader", "Ai Image Generator", "Istock Downloader", "Ninja Seo Tools",
    "Ninja Web Tools", "Domain Search Tools", "Storyblocks Downloader", "Adobe Downloader",
    "Ecomhunt", "Spoke.app", "Smodin_io", "Creatopy", "Hellowscribe", "Rezi.Ai", "Prezi.Ai",
    "Figma", "Visme", "Scite ai", "GPTZero", "1of10.com", "Podcastle.ai", "Loom", "Prowritingaid",
    "Perplexity.ai", "Gnuelements", "lex.page", "123rf", "Cramly", "Writefull", "Fomoclips",
    "Chatpdf", "Vidtoons", "Smodin io", "sobgula","semrush"
]


# Identify mentions of tools in each comment
comment['Tools_Mentioned'] = comment['Content'].apply(
    lambda x: [tool for tool in tools_keywords if tool.lower() in x.lower()]
)

# Count mentions of each tool
tools_mentions = comment.explode('Tools_Mentioned')['Tools_Mentioned'].value_counts()
tools_mentions_dict = tools_mentions.to_dict()

# Plotting
plt.figure(figsize=(20, 6))
tools_mentions.plot(kind='bar', color='skyblue')
plt.title('Frequency of Mentioned Digital Tools')
plt.xlabel('Digital Tools')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
list_data = []
for data in comment['Content']:
    list_data.append(data)

list_data
# Out:
# ['কত',
#  'brilliant  learning app share price?',
#  'lightroom premium price?',
#  'vi envato elements price koto?',
#  'wellsaid labs ai voice lab',
#  'need midjurney',
#  'invido ai?',
#  'grammarly price?',
#  'canva lifetime কত টাকা?',
#  'ভিপিএন গুলো প্রিমিয়াম কত দিনের?',
#  'cyberghost vpn sell koren?',
#  'scribd?',
#  'skillshare er price plz',
#  'trial ase ki?',
#  'creative could koto',
#  'scribd',
#  'chatgpt available?',
#  'litcharts available?',
#  'renderforest ase ki',
#  'coursera price?',
#  'spotify and chatgpt plus price please.',
#  'coursera price?',
#  'semrush tool acee?',
#  'chatgpt & udemy premium koto?',
#  'এই সফটওয়্যার গা কি হবে??\n\nhttps://scontent.fdac134-1.fna.fbcdn.net/v/t39.30808-6/450095356_1438945267505239_9112628533560275368_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=bd9a62&_nc_eui2=aefyux2hew6szgndtw6kxksrvl4e6oqrd3xwxgtqhct3fapmypiynatg3feaaygs33iubwnbuyssyuzvyvsuy0lh&_nc_ohc=w65derd575kq7knvghxnuh-&_nc_zt=23&_nc_ht=scontent.fdac134-1.fna&_nc_gid=agpzkcsm2e_lsbjfkw1poap&oh=00_ayb04mroex0dgk1n64tc27vzsub7jlugpmfkev2elb3jkw&oe=673ac6c8',
#  'linkedin?',
#  'vai amar ekta simurelay subscription korte hobe',
#  'coursera price?',
#  'coursera koto kore?',
#  'semrush available?',
#  'cousera and office 365 price?',
#  'how much for working and educational combo',
#  'coursera 1 year koto?',
#  '৩ দিন না হতেই গ্রামারলি সাইন আউট হয়ে গেছে। এখন আর ঢুকতে পারছি না।',
#  'win10+ adobe cloud price?',
#  'zoom premium version available?',
#  'bin number koto?',
#  'udemy koto',
#  'grammarly koto 1 year',
#  'vidiq ase? \n1 year koto',
#  'price',
#  'hix ai koto',
#  'iilevenlabs dite parbn ki?',
#  'vizard.ai hbe ki??',
#  'coursera',
#  'quilbot and turnitin price?',
#  'semrush price',
#  'freepik 1 month koto tk',
#  'adobe xd price?',
#  'freepik ১ মাসের জন্য কতো?',
#  'udemy কত?',
#  'adobe photoshop cc 2024 ase?',
#  'আপনাদের কাছে কি maya & videoscribe এই সফটওয়্যার পাওয়া যাবে?',
#  'zoom meeting?',
#  'canva pro ??',
#  'jenny.ai lagbe',
#  'youtube premium',
#  'udemy price',
#  'picsart available ?',
#  'express for pc. price?',
#  'udemy subscription kto taka.?',
#  'vai a freepik koto',
#  'typeset available?',
#  'coursera?',
#  'spotify?',
#  'idm price koto??',
#  'coursera available?',
#  'koto',
#  'chatgpt koto price?',
#  'udemy koto?',
#  'udemy price?',
#  'elsa speak ase?',
#  'express vpn ache',
#  'idm koto vai',
#  'chatgpt price?',
#  'price chart of all service',
#  'vpn koto??',
#  'idm price?',
#  'coursera+ 1 year price?',
#  'freepik',
#  'just udemy price?',
#  'adobe animated hobe?',
#  'transkriptor',
#  'transkriptor hobe ki',
#  'artgrid lagbay daua jabay?',
#  'coursera?',
#  'vai capcut pro hobe',
#  'microsoft office price please?',
#  'telegram koto?',
#  'creative could koto',
#  'chatgpt and coursera price?',
#  'bandlab premium hobe ki',
#  'adobe koto?',
#  'bandlab premium hobe ki',
#  'flutter with dart programming?',
#  'vpn price?',
#  'https://www.veed.io/\n\nis this available?',
#  '𝘖𝘧𝘧𝘪𝘤𝘦 2021\n𝘐𝘋𝘔 𝘢𝘤𝘵𝘪𝘷𝘦𝘵𝘦𝘥 𝘭𝘪𝘦𝘢𝘯𝘤𝘦 𝘢𝘮𝘪 𝘶𝘴𝘦 𝘬𝘰𝘳𝘪 𝘰𝘯𝘦𝘬 𝘥𝘪𝘯 𝘩𝘰𝘪 𝘬𝘰𝘯 𝘱𝘳𝘰𝘣𝘭𝘦𝘮 𝘯𝘦𝘪.',
#  'canva pro koto',
#  'quilbot achey?',
#  'grammarly koto?',
#  'udemy',
#  'chatgpt ar creative cloud koto ভাইয়া',
#  'udemy price and validation time',
#  'creative cloud koto',
#  'bhai aktu detail bolle valo hoy',
#  'try hack me available?',
#  'elementor koto?',
#  'chatgpt plus price please',
#  'udemy?',
#  'linkedin premium price??',
#  'envato elements price + download per day',
#  'price?',
#  'canva pro koto?',
#  'price',
#  'need some resorses',
#  'coursera?',
#  'turnitin price',
#  'chatgpt 4 premium available? and price?',
#  'qᴜɪʟʙᴏʟᴛ ᴋᴏᴛᴏ',
#  'আইডিএম কত??',
#  'price',
#  'facebook like & followers \nসার্ভিস নিতে চাইলে ইনবক্স করুন',
#  'kittl ai asee?',
#  'wps pro and zoom pro koto',
#  'auto cad electrical  ache?',
#  'vectorizer ai এর subscription হবে',
#  'grammarly koto?',
#  'vy filmora koto onli',
#  'chatgpt',
#  'truecaller?',
#  'chatgpt4 koto?',
#  'artlist.oi hobay?',
#  'chatgpt premium price কত?',
#  'আইফোনের জন্য truecaller premium প্রাইস প্লিজ',
#  'envato hobe?',
#  'chatgpt pricing?',
#  'turintirin 1 month?',
#  'shutterstock ace?',
#  'virbo ai ache?',
#  'price',
#  'in videi ai ase mod apps ba subscription koto',
#  'vid iq koto?',
#  'udemy koto ?',
#  'udemy courses need',
#  'chat gpt koto',
#  'mid journey acche',
#  'adobe creative cloud price koto?',
#  '1. chatgpt plus\n2. zoom\n3. canva\n4. youtube premium\n\ntotal koto?',
#  'window 11 price?',
#  'i need samrash, canva pro, chatgpt premium, quillbot, and grammarly',
#  'udemy koto?',
#  'is gravity write available?',
#  'turnitin instructor acc and hix price?',
#  'gpt price?',
#  'pacdora atar hobe',
#  'freepik kato?',
#  'adobe cc er dam koto?',
#  'midjourney needed',
#  'topview.ai ache?',
#  'grammarly koto?',
#  'istock available..?',
#  'tarnitin',
#  'udemy available??',
#  'relume hobe?',
#  'price koto',
#  'nord vpn price',
#  'duolingo koto?',
#  'adobe creative cloud koto kore',
#  'elementor pro koto',
#  'ellebenlabs available?',
#  'elavenlabs আছে?',
#  'invideo',
#  'invideo ai naki studio?',
#  'coursera plus price',
#  'chat gpt, leonardo, midjourneh dorkar',
#  'chat gpt koto 4.0 all features',
#  'nord vpn price?',
#  'quilbot koto',
#  'udemy access nai',
#  'coursera',
#  'stealth writer add kren',
#  'runway need',
#  'leonardo ai ache?',
#  'socks5 proxy hobe?',
#  'gpt4 needed',
#  'office 24 ase?',
#  'channel crawler ki ace',
#  'freepik primum price koto',
#  'adobe premier ppro pawa jabe ??',
#  'figma possible',
#  'nice',
#  '🥰🥰🥰🥰',
#  'invideo ai monthly kotogulu video make kora jabe abong eleven lab atate adda ase kina',
#  'nice',
#  'নাইস',
#  '🌼🌺❤️\u200d🩹',
#  'coursera price?',
#  'idm price',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465783491_862998889340901_3915706930273420273_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=110&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=qxxoptavgicq7knvgh86xc6&_nc_oc=adir4lgr7whq2pdcmylzoefx3ghs0mrlkejzty1fikd30gh13cq-h5zyem_jwc7zumy&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_ayc83wwvk4p1btdwlgeckluw0ogr-h-ldppettonxyjz4q&oe=67675707',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465756873_862998926007564_7376615731569615050_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=105&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=l5-fh-uymwaq7knvggklcnj&_nc_oc=adhke4se6op_yyrkrcl4b9yiipzw8gqpaz3wdm9aqgncxn3h3xtrbav2fetonw4a53a&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_ayab8j1m_oaxfkegza-ayte57ysxytkrzviqgvd-4auxrw&oe=676785fe',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465889864_862998982674225_5648967310406177799_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=102&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=coz0dvoqolyq7knvgelgdyv&_nc_oc=adhjmc3bsaubtzvkkjxounvtfdanzkmjfrlybvx-m09i1pxkuhn0fvyemjnigta-njc&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_ayaxemzpho_xmk919ny6dh1cy44gucrkhluzbvccgfryyg&oe=67678931',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465859626_862999032674220_5132252421941844461_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=104&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=5h_zbarejwaq7knvge6-ocy&_nc_oc=adg3k-xtawqr2dfifh2qgtbdhq92y9mbqeyv49k4kdzpdfdscuvonegxjpantstlhg4&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_aycorosyz5ftxaef5b_4ehvx97yoqlksonlpkqogiefpiw&oe=67677ef2',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465772130_862999076007549_3576416861749224701_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=104&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=pjcjwalxmo8q7knvgehjxaj&_nc_oc=adhndjeskpfxasigixqi99pfv_nfxodctwc_9ebbszcd4hyieszll3mqmruqhroi2m0&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_aybyrk2xovqzipjpieqtbpq-4kqacuxc6plmpv7tkjn5iq&oe=67675769',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465744613_862999149340875_7195415485991649867_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=110&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=nkzppwniyjwq7knvge8ts7p&_nc_oc=adgliw-nwgcnpqaqncoaey8bx4zshc7xecubwrhozpxmqfmooexkihhn-78ydrqk98k&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_ayacmjep2cvik96o5dir5rsotk2z8vekcxqmxwyvqb8pva&oe=676778c5',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465788613_862999199340870_3309947214393278725_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=103&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=mnmzve8yybiq7knvghm59y9&_nc_oc=adi0qvzt-pfeuwqj47ludcbjp_3dkfvrw-s09skmv-iyy1hchj1hjkc7okusw7yqsne&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_ayaf8nqmsjuydicqm7-7pzcln8gdf3vbz5cjr4izo_rerq&oe=676773db',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465800278_862999249340865_2457650925330434721_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=107&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=qi97cmski3sq7knvgerxiox&_nc_oc=adidm38rbnvvbufswfzepgspckcxgoakyzoxfrubgxvrbfylj4loc57fdfid-qnxqry&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_aycbieg5m9vxv6oz5c2evyuun4wlk21towachvsrluo7bg&oe=67678ae6',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465859872_862999306007526_4506203862991164509_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=100&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=eftgtlmdtqeq7knvghzldre&_nc_oc=adiyk0p7za3sbaocnpr6jgs-ybqq1xmoznxoopwbym4rhcnxkmv3rn3y1w7dt6zezxw&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_aydk-hrsrcfei0o4fdt2idpu_zexl5_zuymzrfmd38eudq&oe=676775eb',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465789308_862999369340853_2906867717378923761_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=111&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=vyfh03ruwgeq7knvggk3qzw&_nc_oc=adj8sipxbdiw7irnsgvmw3n7uwd16_wa1za35pveiau5divvmgh21a6e82c_ijdqwbk&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_aybmennz9lvts0_mvs88bopimehpjdtikkbv92ahm0g11g&oe=67677851',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465782292_862999436007513_5681234534562451313_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=110&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=f_vae8znt1aq7knvgfaghu9&_nc_oc=adhkrcj3hlj5bluy3ow8ntqhabfdvknzlrb1nwd5goqahw7fam_mpsyepvwatvrjkow&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_ayabmyyghm4ixfeoh90hfmxgkotsekczs4a9u8rfzljdsa&oe=6767571b',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465789495_862999486007508_9191640361384719464_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=108&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=aecqrff-w_uq7knvgemch77&_nc_oc=adhhi0r8nr8n1jaxafbbdnlrb3qxudyxci4mk1nlj7gyfp_9noj96j_fp85m3eu9ut8&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_aychbgsbxsds_fxzlquq2ntq9heqwey2of29e7lztettxw&oe=6767598e',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465859651_862999522674171_5167425944615470989_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=106&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=monlg6gsy8wq7knvgeuwtzc&_nc_oc=adjtfdrdn1pari4qe9ffw3tiqgk5jnlxkgsdjqvrphghsodb11h26iqm6sy680q_g_0&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_aycchpeq0adejfbx6qzl1atxz2iioyc5n9pxb1z7q-wria&oe=676786d6',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465782093_862999596007497_2148653518807376450_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=5afqkjf33wsq7knvgexptci&_nc_oc=adhyneaw962fbnk90jnf_c3twl8chtn2guvspxbfogl89sfu94b0vaw9psqznwk-cgg&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_aybi2rjltkq1r2f-zv9izpgicjmunxzw_pb6od8lr-ru1a&oe=67677215',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465847352_862999652674158_713988386439032019_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=106&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=kisfrdkkvmkq7knvghyz6-2&_nc_oc=adgftfkv3ei7yhg6lau4ihkoziu2tddiqwi5jcdomjzbat91arvo36_8xi83n2fset8&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_aycv19lfvtvwl2ceyct0pr9jmp2bjmuhkmsnytbvncvbna&oe=676754a9',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465784177_862999722674151_8625913100069975028_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=105&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=acfc6ybaodiq7knvgg3z7wb&_nc_oc=adg7qzlcqcok_th5petvikqb8qubpgi0c_jowglmj3qh3wd8hfj-amnzqfqunxaex6w&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_ayap4ptdm7rkxf0v9kltqtdwzizdgcfb4kd2iuhfhvixig&oe=67676141',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465787143_862999766007480_6617279961171678349_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=111&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=hfhlndafjtgq7knvgeieiv-&_nc_oc=adgbvbrgjf0xerharnqqid4a7ameykhp9xi-dir7lugx4bn7yvuc_crteg0inmfmvhc&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_aybmwestrktleheufcoiwdxgnzfn6yvlw8vpnpe7obyblq&oe=67676287',
#  'smartshort ai',
#  'কিনব',
#  'scalenut আছে',
#  'indexification available??',
#  'helium 10 ache?',
#  'youtube এ ব্যবহৃত  tools কত?',
#  'semrusher shthe kon 3ta gift diben?',
#  'endnote available?',
#  'amar lagbe but complete setup bujie dite hobe',
#  '1 month package  e ki 120+ tools use kora jabe',
#  'leanardo ai price?',
#  '🖤',
#  'md faisal ভাই করলেন ডা কি\U0001fae3\U0001fae3🥰🥰 নিয়া নিলাম।🤭',
#  'backlink indexer tools ase',
#  'daily limit koto',
#  'reza talukder',
#  'daily limit and ki ki feature??  kon panel?',
#  'daily limit for ahref',
#  'ahref, semrush,moz price koto eksonge nile',
#  'kotodin meyad',
#  'leonardo?',
#  '50+ full list dia jabe?',
#  'what is the the daily limit of usage for ahrefs?',
#  'ahrefs a koto credit pabo per day?',
#  'daily limit and ki ki feature??  kon panel?',
#  'price',
#  'daily limit for ahrefs?',
#  'ahrefs eto dam keno?  tools ki ektai?',
#  'stealthwriter ace?',
#  'price?',
#  'really good service',
#  'kivabe pabo?',
#  'semrush price?',
#  'semrush kotho',
#  'good service 👍',
#  'ডেইলি ক্রেডিট লিমিট?',
#  'daily limit koto vai',
#  'semrush,grammerly, canva 3tar package ache?',
#  'i think they provide good services.',
#  'semrush price?',
#  'need it',
#  'ahref, semrush,moz price koto eksonge nile',
#  'we are best and trusted seller 😍\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465838343_407006622482749_3170663742057725845_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=4rdmrrfejweq7knvgho07jf&_nc_oc=adhxgj-qxnb_im2fnjapo9omt1vs1ylioy7pp35o2wffythrp1qxsf5qdjknznnzvsw&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=atxrcfkbj0p89ndry-ozkgy&oh=00_ayaqmlmoqdbku0qufscgnpkzn57_mejc-9mgnshofewtsw&oe=67675c06',
#  'aida kichu hoilo!!! ami niya nilei offer ashe ken😭😭😭???',
#  'aje semrush tool na nelam daki kamon service pai apner akne',
#  'khub vlo service sob somoy vlo e asa korbo vi apnr thaky🖤',
#  'content explore কয়টা করে পাবো?',
#  'envato koto?',
#  'pp',
#  'semrush koto',
#  'turninit price?',
#  'price ?',
#  'yrs',
#  'pp',
#  'yes',
#  'basic youtube seo kaj pari. vidiq nila amr jonno valo hba',
#  'masha allah vai',
#  '❤️🥰',
#  'আমি কিভাবে পেতে পারি?ভাই',
#  'yes',
#  'great',
#  'yes',
#  '❤️❤️❤️',
#  'vidiq+semrush+chatgpt কম্বো হবে?',
#  'kivaby pabo',
#  'best service',
#  'mashallah best service',
#  'mashaallah',
#  '❤️',
#  'ভাই আমার লাগবে',
#  'আমরা যারা কিনি নাই তারা কি ফ্রী পাবো ৫ দিন??',
#  'great service😍',
#  'price? kibabe nibo?',
#  'vidiq 6 month subscription koto?',
#  'price',
#  'pp',
#  'price',
#  'ma sha allah ❤️',
#  'amar lagbe',
#  'vidiq boost and semrush pro plan koto??',
#  'ফয়সাল ভাইয়ের টুলস এর সার্ভিস এক কথায় বলা যায় অসাধারণ এবং ভাইয়ের সাপোর্ট মেম্বারদের কথা তো আর নাই বললাম, রাত তিনটার নয় চারটা নাই যখন এই এসএমএস দিই তখনই তারা আমাদের রেসপন্স করে। \n💘💓💗💖💝💞💞',
#  'price',
#  'hm?',
#  'faisaliteb seo tools check inbox pls',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/449148492_316095051573907_3263288004513382613_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=or1m2jg7oteq7knvghgf4k6&_nc_oc=adhadehmblr4r8yhur969j1zozdxktpz3liokn-_1yfcge2whi0mzpo5zxdmsneos8y&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=adw5nhq5aj1f77cjjm0g9ua&oh=00_ayd9yyjqt5etq9rfjfpque8jbpdrpe1wwdsladauc8p0sg&oe=67675b34',
#  'price?',
#  'price',
#  'vidiq 1 month price',
#  'how much?',
#  'price',
#  'price',
#  '🖤',
#  'md faisal ভাই করলেন ডা কি\U0001fae3\U0001fae3🥰🥰 নিয়া নিলাম।🤭',
#  'backlink indexer tools ase',
#  'daily limit koto',
#  'reza talukder',
#  'daily limit and ki ki feature??  kon panel?',
#  'daily limit for ahref',
#  'ahref, semrush,moz price koto eksonge nile',
#  'kotodin meyad',
#  'leonardo?',
#  '50+ full list dia jabe?',
#  'what is the the daily limit of usage for ahrefs?',
#  'ahrefs a koto credit pabo per day?',
#  'daily limit and ki ki feature??  kon panel?',
#  'price',
#  'daily limit for ahrefs?',
#  'ahrefs eto dam keno?  tools ki ektai?',
#  'stealthwriter ace?',
#  'price?',
#  'really good service',
#  'kivabe pabo?',
#  'semrush price?',
#  'semrush kotho',
#  'good service 👍',
#  'ডেইলি ক্রেডিট লিমিট?',
#  'daily limit koto vai',
#  'semrush,grammerly, canva 3tar package ache?',
#  'i think they provide good services.',
#  'semrush price?',
#  'need it',
#  'ahref, semrush,moz price koto eksonge nile',
#  'we are best and trusted seller 😍\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465838343_407006622482749_3170663742057725845_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=4rdmrrfejweq7knvgho07jf&_nc_oc=adhxgj-qxnb_im2fnjapo9omt1vs1ylioy7pp35o2wffythrp1qxsf5qdjknznnzvsw&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a_ay2w4n3i0rlnl02ipc0wg&oh=00_aycympl8kmhw7qv5mxvwflbwmpvlsv-hjxtwsbagofocjg&oe=67675c06',
#  'aida kichu hoilo!!! ami niya nilei offer ashe ken😭😭😭???',
#  'aje semrush tool na nelam daki kamon service pai apner akne',
#  'khub vlo service sob somoy vlo e asa korbo vi apnr thaky🖤',
#  'content explore কয়টা করে পাবো?',
#  'envato koto?',
#  'pp',
#  'semrush koto',
#  'turninit price?',
#  '🖤',
#  'md faisal ভাই করলেন ডা কি\U0001fae3\U0001fae3🥰🥰 নিয়া নিলাম।🤭',
#  'backlink indexer tools ase',
#  'daily limit koto',
#  'reza talukder',
#  'daily limit and ki ki feature??  kon panel?',
#  'daily limit for ahref',
#  'ahref, semrush,moz price koto eksonge nile',
#  'kotodin meyad',
#  'leonardo?',
#  '50+ full list dia jabe?',
#  'what is the the daily limit of usage for ahrefs?',
#  'ahrefs a koto credit pabo per day?',
#  'daily limit and ki ki feature??  kon panel?',
#  'price',
#  'daily limit for ahrefs?',
#  'ahrefs eto dam keno?  tools ki ektai?',
#  'stealthwriter ace?',
#  'price?',
#  'really good service',
#  'kivabe pabo?',
#  'semrush price?',
#  'semrush kotho',
#  'good service 👍',
#  'ডেইলি ক্রেডিট লিমিট?',
#  'daily limit koto vai',
#  'semrush,grammerly, canva 3tar package ache?',
#  'i think they provide good services.',
#  'semrush price?',
#  'need it',
#  'ahref, semrush,moz price koto eksonge nile',
#  'we are best and trusted seller 😍\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465838343_407006622482749_3170663742057725845_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=4rdmrrfejweq7knvgho07jf&_nc_oc=adhxgj-qxnb_im2fnjapo9omt1vs1ylioy7pp35o2wffythrp1qxsf5qdjknznnzvsw&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=ano3m94_swytda6txkb8ilg&oh=00_aydm07l9e9yeb6mhi60mewryzdob0msnqhan47oborlfda&oe=67675c06',
#  'aida kichu hoilo!!! ami niya nilei offer ashe ken😭😭😭???',
#  'aje semrush tool na nelam daki kamon service pai apner akne',
#  'khub vlo service sob somoy vlo e asa korbo vi apnr thaky🖤',
#  'content explore কয়টা করে পাবো?',
#  'envato koto?',
#  'pp',
#  'semrush koto',
#  'turninit price?',
#  'happy customer\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465378808_122201882732035191_7978964257109334436_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=103&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=tfvfbu7ayswq7knvgfjy1me&_nc_oc=adirje3gkuilr2e__u-lqiaz9kogd3ac2jyehjck7jt6egnh8ms-xbxince9koxfwfw&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=anka1oiq-icm2xl9amvvjtj&oh=00_aybzzlohpjostxiimdeggsu6ahjwct2q9e05sk08o9bjmw&oe=67677105',
#  'vidiq boost panel ache?',
#  'runwayml ?',
#  'price??  details?',
#  'fliki ai ase?',
#  'netflix, prime video and canva lgbe',
#  'pp details',
#  'amar lagbe',
#  'price?',
#  'sayem ahmed shaon',
#  'chatgpt price',
#  'pp?',
#  'invidio',
#  'reselling koren ?',
#  'lifetime- এলে তো একদিন ও দেন না।- এখন পর্যন্ত কত জন থেকে কিনলাম।',
#  'yearly package ase?',
#  'শুধু ai content writing tool কয়টা যেটা দিয়ে কন্টেন্ট রাইটিং করা যায়???',
#  'ager ad  ekhnkr ad',
#  'demo',
#  'renderforest ase?',
#  'chatgpt আছে?',
#  'vidiq happy customer👑❤️\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/469261843_122204692232035191_2916827757351295562_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=111&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=pkoodmatxugq7knvggmatqu&_nc_oc=adjidgclbcml5aokfiksmwzddp-x7ycz6s8xuehesf0rvmxx8po3ohhfczdj7q02xma&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=agnm2sp5patfrymeoxiemtt&oh=00_ayasklutr25ynlsavdrfsfphlkyz0uufboixpmtgtjswla&oe=67675f5a',
#  'chtgpt koto?',
#  'gpt price',
#  'chatgpt koto?',
#  'chatgpt koto?',
#  'next xtrem টাকা মারার ধোকা সাইট ! কেউ ফাদ পা দিবেন না ! অফার নামে টাকা মেরে দায় ! \nসাবধান !',
#  'cracked?',
#  'vpn ase',
#  'invideo ai v3 চেক করে নেওয়া যাবে?',
#  'vaiya tools lagbe\U0001fae1\U0001fae1',
#  'panel a login er maddhome diben? na sorasori gmail a',
#  'bangla te audio to text converter ase kono?? jodi thake tahole 2/3 ta tools nibo bese bese',
#  '11 labs ace',
#  'vidiq koto?',
#  'invideo.io\ninvideo.studio\nকোনটা দিবেন?',
#  'কতো দিন থাকবে',
#  'elevenlabs er subcription paoya jay ki',
#  'neta chi',
#  'nita cai',
#  'eleven labs',
#  'apnara ki pictory.ai er subscription sell koren?',
#  'pictory subscription hobe?',
#  'ahrefs hobe?',
#  'i want this package.',
#  'semrush koto',
#  'limitations?  activity',
#  'sales navigator nai?',
#  'check inbox',
#  'ahref account koto price',
#  'i need',
#  'semush single r group buy er difference ki ?',
#  'keo nicen eder services?',
#  'seo tools golor keywords research ki daily limitations ace and chat gpt plus ki?',
#  'agula limited  nh unlimited',
#  'নিতে চাই',
#  'nuaim chowdhury',
#  'গ্রুপবাই জিনিস টা আমাকে একটু বুজিয়ে বলাযাবে? আর আমি যদি শুধু সেমরাস কিনতে চাই সেটা কি পারবো? প্রাইজ কত পড়বে',
#  'ঈদের পরে লাগবে ইনশাআল্লাহ',
#  'vidiq premium mobile app hobe',
#  'koto din er jonno',
#  'interested',
#  'semrush kon plan thakba like "pro" "guru" "business" and all tools limitation ta bolban .....',
#  'jasper?',
#  '৬৪০৳ কি কি টুলস পাবো যদি একটু ডিটেইল বলতেন',
#  'all software duration ?',
#  'interested',
#  'chat gpt ase?',
#  'আমার দেখা সেরা  সেলার। যারা চিন্তত আছেন জিতবেন নাকি ঠকবেন তারা নিশ্চিন্তে নিতে পারেন। এনাদের সার্ভিস যেমন ভালো আর সাপোর্টও তেমন ভালো। \n\nas a customer i have 100/100 satisfied',
#  "only e'nvato el'ements koto?",
#  'midjourney alternative kisu ase?',
#  'customer support kemon den seta bolen?',
#  'https://external.fdac7-1.fna.fbcdn.net/emg1/v/t13/16307397131285909973?url=https%3a%2f%2fmedia1.tenor.co%2fimages%2fad92ee75959358d5c8616e2b10c8b6cd%2ftenor.gif%3fc%3dvjffzmfjzwjvb2tfd2viy29tbwvudhm%26itemid%3d22216620&fb_obo=1&utld=tenor.co&stp=dst-jpg_flffffff_q75_s396x396_tt6&_nc_oc=adhs1kwtscvoufoi3c8mhhz_lqrt64lecnrb0no8irho9kzjv6a1fexf5o2dfwsq89w&ccb=13-1&oh=06_q399o2u_fx2jm_3eot1y1ahlacvmdudoty-zx526pzclmzc&oe=67636c14&_nc_sid=867500',
#  'কাজ করে নাকি শুধু একাউন্ট?',
#  'md. abdul khaleque bd',
#  'আসি গতমাসে এক জায়গা থেকে নিয়েছিলাম তার অধিকাংশ অকেজো, প্রো ভার্সন লগইন হয় না, এক কথায় 70% ভূয়া। আবার এই মাসে বেশি টাকা দিয়ে আরেক জায়গা থেকে নিয়েছি একই সমস্যা।',
#  'please kindly inbox me…',
#  'only semrush hobe?',
#  'apnader contain generator best tool kongulo?',
#  'surfer seo ase? cost koto?',
#  '❤️❤️❤️❤️',
#  'offer available now????',
#  'jungle scout available ache?',
#  'undetectable .ai available',
#  'money robot submitter ba rankx hobe?',
#  'এখন কি কোনো অফার আছে??',
#  'chatgpt 4 deya hobe naki',
#  'chat gtp 4 ace ei list e',
#  'i am interested , how can i get.',
#  '640 টাকায় কতো দিনের জন্য??',
#  'shutterstock?',
#  'basic plan a  ami ki tool choose kore nite parbo?',
#  'আমি সব টুল নিবো না সেক্ষেত্রে টাকা কি কম দেওয়া যাবে?',
#  'আপনাদের কাছে কন্টেন রাইটিং এর ভালো টুল কোনটি?',
#  'runway ai tool ache ki?',
#  'ahrefs hobe?',
#  'i want this package.',
#  'semrush koto',
#  'limitations?  activity',
#  'sales navigator nai?',
#  'check inbox',
#  'ahref account koto price',
#  'i need',
#  'semush single r group buy er difference ki ?',
#  'keo nicen eder services?',
#  'seo tools golor keywords research ki daily limitations ace and chat gpt plus ki?',
#  'agula limited  nh unlimited',
#  'নিতে চাই',
#  'nuaim chowdhury',
#  'গ্রুপবাই জিনিস টা আমাকে একটু বুজিয়ে বলাযাবে? আর আমি যদি শুধু সেমরাস কিনতে চাই সেটা কি পারবো? প্রাইজ কত পড়বে',
#  'ঈদের পরে লাগবে ইনশাআল্লাহ',
#  'vidiq premium mobile app hobe',
#  'koto din er jonno',
#  'interested',
#  'semrush kon plan thakba like "pro" "guru" "business" and all tools limitation ta bolban .....',
#  'jasper?',
#  '৬৪০৳ কি কি টুলস পাবো যদি একটু ডিটেইল বলতেন',
#  'all software duration ?',
#  'interested',
#  'chat gpt ase?',
#  'আমার দেখা সেরা  সেলার। যারা চিন্তত আছেন জিতবেন নাকি ঠকবেন তারা নিশ্চিন্তে নিতে পারেন। এনাদের সার্ভিস যেমন ভালো আর সাপোর্টও তেমন ভালো। \n\nas a customer i have 100/100 satisfied',
#  "only e'nvato el'ements koto?",
#  'midjourney alternative kisu ase?',
#  'customer support kemon den seta bolen?',
#  'https://external.fdac7-1.fna.fbcdn.net/emg1/v/t13/16307397131285909973?url=https%3a%2f%2fmedia1.tenor.co%2fimages%2fad92ee75959358d5c8616e2b10c8b6cd%2ftenor.gif%3fc%3dvjffzmfjzwjvb2tfd2viy29tbwvudhm%26itemid%3d22216620&fb_obo=1&utld=tenor.co&stp=dst-jpg_flffffff_q75_s396x396_tt6&_nc_oc=adhs1kwtscvoufoi3c8mhhz_lqrt64lecnrb0no8irho9kzjv6a1fexf5o2dfwsq89w&ccb=13-1&oh=06_q399o2u_fx2jm_3eot1y1ahlacvmdudoty-zx526pzclmzc&oe=67636c14&_nc_sid=867500',
#  'কাজ করে নাকি শুধু একাউন্ট?',
#  'md. abdul khaleque bd',
#  'আসি গতমাসে এক জায়গা থেকে নিয়েছিলাম তার অধিকাংশ অকেজো, প্রো ভার্সন লগইন হয় না, এক কথায় 70% ভূয়া। আবার এই মাসে বেশি টাকা দিয়ে আরেক জায়গা থেকে নিয়েছি একই সমস্যা।',
#  'please kindly inbox me…',
#  'only semrush hobe?',
#  'apnader contain generator best tool kongulo?',
#  'surfer seo ase? cost koto?',
#  '❤️❤️❤️❤️',
#  'offer available now????',
#  'jungle scout available ache?',
#  'undetectable .ai available',
#  'money robot submitter ba rankx hobe?',
#  'এখন কি কোনো অফার আছে??',
#  'chatgpt 4 deya hobe naki',
#  'chat gtp 4 ace ei list e',
#  'i am interested , how can i get.',
#  '640 টাকায় কতো দিনের জন্য??',
#  'shutterstock?',
#  'basic plan a  ami ki tool choose kore nite parbo?',
#  'আমি সব টুল নিবো না সেক্ষেত্রে টাকা কি কম দেওয়া যাবে?',
#  'আপনাদের কাছে কন্টেন রাইটিং এর ভালো টুল কোনটি?',
#  'runway ai tool ache ki?',
#  'writersonic add koren',
#  'kiser kiser web acche',
#  'only semrush kotoh',
#  'sob kichu 850 ?',
#  'vidiq pro acess powa jabe',
#  'semrush  এর লিমিট কত?',
#  'pictory hobe?',
#  'semrush konta diben...?',
#  'quillbot ,surfshark vpn ১ বছরের জন্য কত টাকা ?',
#  'only semrush koto',
#  'ahrefs nai kno??',
#  'play.ht text to voice ai tool ta dorkar. ase kina?',
#  'inbox me',
#  'do you have fliki.ai?',
#  'spy tools ache?',
#  'semrush chai',
#  'semrush er linkd en',
#  'only powtoon hobe ki, hole fee koto?',
#  'pictory ta hobe??',
#  'kotodin er plan bhai?',
#  'kotodin lagbe bhai?',
#  'only semrush ar canva nile kamon porbe?',
#  'kom hole bolben',
#  'rank math ace?',
#  'copy closer tools ki ache?',
#  'service ki valo hoba',
#  'envato elements er cost koto?',
#  'amazon research tools available?',
#  'ফ্রিল্যান্সিং opportunity ⤵️\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/337862139_486983613516856_2493655937544722175_n.jpg?stp=dst-jpg_p75x225_tt6&_nc_cat=109&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=41ilchflqksq7knvghnqfvd&_nc_oc=adg10opvgsrbjaezyrst9j6mp0b4euer9eftxkha8pv6zyh3besltmrgfqg7xt0vpuk&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=aevtczcbp0hpnrx05n9gcof&oh=00_aydywbd7jvvxtq0c1m4n03oesr5ng5twdcifdpunxtn4rq&oe=676786c8',
#  'f',
#  'yoast seo?',
#  'ahrefs tools available',
#  'gramarly, word ai,woo rank 6 months koto porbe',
#  'how',
#  'åhøshàñ hâßïß ríyåd',
#  'only semrush.\nmonthly or what other type subscriptions?',
#  'murf ai?',
#  'semrush & article builder\nprice',
#  'murf',
#  "$emr**sh (সেম রাশ),keyword r'evealer (bonus) ki premium",
#  'কন্টেন্ট রাইটিং এর টুলস আছে আপনার কাছে',
#  'ahrefs+ semruch koto?',
#  'jasper আছে কি',
#  'hi',
#  'article writing er jonno konta ace',
#  'only need moz premium',
#  'chat gpt plus available?',
#  'please inbox in details...',
#  'lead generation er tools hobe???',
#  'semrush hobe bhaia?',
#  'vidiq koto',
#  'give me basic plan details?',
#  '❤️',
#  'standard plan - 35+ tools - 500 takai deya jabe  tk',
#  'blog cutter ,jasper, smodin hobe ki',
#  'writersonic add koren',
#  'kiser kiser web acche',
#  'only semrush kotoh',
#  'sob kichu 850 ?',
#  'vidiq pro acess powa jabe',
#  'semrush  এর লিমিট কত?',
#  'pictory hobe?',
#  'semrush konta diben...?',
#  'quillbot ,surfshark vpn ১ বছরের জন্য কত টাকা ?',
#  'only semrush koto',
#  'ahrefs nai kno??',
#  'play.ht text to voice ai tool ta dorkar. ase kina?',
#  'inbox me',
#  'do you have fliki.ai?',
#  'spy tools ache?',
#  'semrush chai',
#  'semrush er linkd en',
#  'only powtoon hobe ki, hole fee koto?',
#  'pictory ta hobe??',
#  'kotodin er plan bhai?',
#  'kotodin lagbe bhai?',
#  'only semrush ar canva nile kamon porbe?',
#  'kom hole bolben',
#  'rank math ace?',
#  'copy closer tools ki ache?',
#  'service ki valo hoba',
#  'envato elements er cost koto?',
#  'amazon research tools available?',
#  'ফ্রিল্যান্সিং opportunity ⤵️\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/337862139_486983613516856_2493655937544722175_n.jpg?stp=dst-jpg_p75x225_tt6&_nc_cat=109&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=41ilchflqksq7knvghnqfvd&_nc_oc=adg10opvgsrbjaezyrst9j6mp0b4euer9eftxkha8pv6zyh3besltmrgfqg7xt0vpuk&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=amrst-zupey2oe-el-sr3um&oh=00_aydej43nn0cmslvasbhkjbovbecfrrorigc5vx3uqwgqhg&oe=67674e88',
#  'f',
#  'yoast seo?',
#  'ahrefs tools available',
#  'gramarly, word ai,woo rank 6 months koto porbe',
#  'how',
#  'åhøshàñ hâßïß ríyåd',
#  'only semrush.\nmonthly or what other type subscriptions?',
#  'murf ai?',
#  'semrush & article builder\nprice',
#  'murf',
#  "$emr**sh (সেম রাশ),keyword r'evealer (bonus) ki premium",
#  'কন্টেন্ট রাইটিং এর টুলস আছে আপনার কাছে',
#  'ahrefs+ semruch koto?',
#  'jasper আছে কি',
#  'hi',
#  'article writing er jonno konta ace',
#  'only need moz premium',
#  'chat gpt plus available?',
#  'please inbox in details...',
#  'lead generation er tools hobe???',
#  'semrush hobe bhaia?',
#  'vidiq koto',
#  'give me basic plan details?',
#  '❤️',
#  'standard plan - 35+ tools - 500 takai deya jabe  tk',
#  'blog cutter ,jasper, smodin hobe ki',
#  'alhamdulillah, i received a lot of good service from the brothers',
#  'nord vpn account\n১ বছরের মেয়াদে কম দামে সেল দেওয়া হবে।\nজিমেইল পাসওয়ার্ড সহ দিয়ে দেওয়া হবে।\nলাগলে ইনবক্স।।।',
#  'nord vpn  6month',
#  'cyber ghost  koto',
#  'nord koto',
#  'express vpn',
#  'surf shark koto',
#  'ip vanish koto',
#  'https://social-earn.top/509054744791',
#  'ip vanish koto',
#  'they are great in service pls keep up',
#  'nord price',
#  'lifetime access pabo??',
#  'আমাদের কাছে রয়েছে chat gpt সহ আরো অনেক জনপ্রিয় টুলস তাই এখনি ভিজিট করুন  আপনার পচ্ছন্দের টুলস buy করতে :-  https://faisalitebtools.com/',
#  '🔥 buy now and instant access visit : https://faisalitebtools.com/\nand we are trusted seller',
#  'সাথে আরো কিছু দিলে ভাল হইত \U0001fae3',
#  'সবকিছু বললেন কিন্তু প্রাইস বললেন না এটা হলো?',
#  '6 manth koto',
#  'price?',
#  'price koto?',
#  'faisaliteb seo tools bhaijan 1 monther jonno price koto..?\nchatgpt nile alada koto lagbe?',
#  'vi r kisu ni',
#  'price?',
#  '#freelancingschoolbdbyrifat\nhttps://youtu.be/lqpk8vwhjuo?si=eqvn232cc8a5ggs9',
#  'one month price',
#  '1year price',
#  'p',
#  'price??',
#  'price koto?',
#  'আপনাদের সার্ভিস টা আসলেই অনেক ভালো \nএরকম সার্ভিস কন্টিনিউ থাকলে আর অন্য কোথাও থেকে কিনতে হবে না',
#  'hello',
#  'price',
#  'grammerly koto',
#  'price',
#  'ekhane ki backlink possible..? r backlink korle index hoar possiblity koto toku...?',
#  'semrush seo tools er price koto? for 1 month or 3 month.',
#  'আমার শুধু semrush লাগবে কত টাকা লাগবে বলবেন প্লিজ',
#  '6 month koto?',
#  'price?',
#  'price?',
#  'price',
#  'prize koto vai?',
#  'price',
#  'আপনাদের সার্ভিস আমার ব্যক্তিগত ভাবে অনেক ভালো লাগছে। আপনাদের টিম মেম্বারদের অমায়িক আচরণ দেখে আমি মুগ্ধ। আসা করি এইভাবে আপনাদের সফলতা অনেক দূর এগিয়ে নিয়ে যাবেন 😘❤️',
#  'ekhon ki ai tools nite parbo?',
#  'ptice',
#  'price',
#  'best tools service ❤️',
#  'lifetime',
#  'canva pro koto',
#  "𝐒𝐄𝐌'𝐫𝐮𝐬𝐡 𝐆𝐮𝐫𝐮 𝐏𝐥𝐚𝐧 lagbe",
#  'pp',
#  'price?',
#  'mayad kotodin',
#  'best service thanks',
#  'price koto',
#  'semrush seo tools er price koto? for 1 month or 3 month.',
#  'semrush কতো?',
#  'no limitations  মানে কি ভাই?  ১মাসের বেশি ব্যবহার করা যাবে semrush 🤔',
#  'price kto bhai?',
#  'vectorizer ai subscription হবে',
#  'price?',
#  'price please?',
#  'canva bade chat gpt plus add kore diben',
#  'price',
#  'price koto',
#  'মাস কত',
#  'price koto? ar  koto diner jonno?',
#  'semrush লাগবে',
#  'দাম',
#  'pp?',
#  'lovely ❣️👍🏻',
#  'grammerly & chatgpt price?',
#  'price',
#  'price please sir',
#  'price',
#  'price?',
#  'price?',
#  'স্যার ডিস্কাউন্ট দেবেন না?😌',
#  'koto din?',
#  'limitation?',
#  'details please',
#  '30 din por abar access cole jabe?',
#  'interested',
#  'service kemon?',
#  'lifelife membership ase ki',
#  'details please',
#  'ahrefs tool nai',
#  'কত দিনের জন্য?',
#  'have your others tools?',
#  'price',
#  'interested',
#  'details please',
#  'আমি বুঝিনা এটা, $120 ডলার বা ১২০০০ পার মান্থ এর একটা টুলস আপনারা কিভাবে ৩৯৯ টাকায় দেন!',
#  'কোনো লিমিটেশন আছে?',
#  'vaiya ota ki 1 month limit nki',
#  'koto diner jonno eita',
#  'ata ki monthly service',
#  'koto gula site audit kora jabe',
#  'ahrefs den?',
#  'details \nplease',
#  'details plz',
#  'available guru plan',
#  'details please',
#  'details please',
#  '399 tk ki 1 month warranty',
#  'i need discount',
#  'এনাদের সার্ভিস অনেক ভাল আজকেই নিলাম এডমিন ভাইয়ের বিহেভিয়ার ভাল ছিল, আশা করি ইউজার এক্সপেরিয়েন্স ভাল হবে 🙂',
#  'kivabe use korbo',
#  'price??',
#  'with site audit feature?',
#  'details please.',
#  'details please',
#  '399tk=koto months',
#  'monthly 399?',
#  'aherfs',
#  'kebol semrush + moze kinlam. \n\nquick and helpful\n\napnra o kinte paren',
#  '399 takay 1 month???',
#  '1 weak er jonno nite chai',
#  'interested',
#  'সব ফিচার পাওয়া যাবে? কয়টা প্রোজেক্ট অ্যাড করা যাবে? টক্সিক লিংক রিমুভ সহ সব ধরবের এরর আর ওয়ারনিং দেখাবে? আর সব চেয়ে ইম্পরট্যান্ট মাস শেষে নতুন করে রিনিউবকরা পসিবল কিনা?',
#  'access kiser madhome diya hoy?',
#  'details please',
#  'details plz',
#  'লাইফটাইম প্লান কত?',
#  'মেয়াদ?',
#  'ahrefs available?',
#  'এই অফার কতদিন চলবে?',
#  'ai ta ki sharing ?',
#  'details pls',
#  'project add koyta kora jay?',
#  'koto din',
#  'do u have ahrefs?',
#  'available?',
#  'lifetime access pabo??',
#  'আমাদের কাছে রয়েছে chat gpt সহ আরো অনেক জনপ্রিয় টুলস তাই এখনি ভিজিট করুন  আপনার পচ্ছন্দের টুলস buy করতে :-  https://faisalitebtools.com/',
#  '🔥 buy now and instant access visit : https://faisalitebtools.com/\nand we are trusted seller',
#  'সাথে আরো কিছু দিলে ভাল হইত \U0001fae3',
#  'সবকিছু বললেন কিন্তু প্রাইস বললেন না এটা হলো?',
#  '6 manth koto',
#  'price?',
#  'price koto?',
#  'faisaliteb seo tools bhaijan 1 monther jonno price koto..?\nchatgpt nile alada koto lagbe?',
#  'vi r kisu ni',
#  'price?',
#  '#freelancingschoolbdbyrifat\nhttps://youtu.be/lqpk8vwhjuo?si=eqvn232cc8a5ggs9',
#  'one month price',
#  '1year price',
#  'p',
#  'price??',
#  'price koto?',
#  'আপনাদের সার্ভিস টা আসলেই অনেক ভালো \nএরকম সার্ভিস কন্টিনিউ থাকলে আর অন্য কোথাও থেকে কিনতে হবে না',
#  'hello',
#  'price',
#  'grammerly koto',
#  'price',
#  'ekhane ki backlink possible..? r backlink korle index hoar possiblity koto toku...?',
#  'semrush seo tools er price koto? for 1 month or 3 month.',
#  'আমার শুধু semrush লাগবে কত টাকা লাগবে বলবেন প্লিজ',
#  '6 month koto?',
#  'price?',
#  'price?',
#  'price',
#  'prize koto vai?',
#  'price',
#  'আপনাদের সার্ভিস আমার ব্যক্তিগত ভাবে অনেক ভালো লাগছে। আপনাদের টিম মেম্বারদের অমায়িক আচরণ দেখে আমি মুগ্ধ। আসা করি এইভাবে আপনাদের সফলতা অনেক দূর এগিয়ে নিয়ে যাবেন 😘❤️',
#  'ekhon ki ai tools nite parbo?',
#  'ptice',
#  'price',
#  'best tools service ❤️',
#  'lifetime',
#  'canva pro koto',
#  "𝐒𝐄𝐌'𝐫𝐮𝐬𝐡 𝐆𝐮𝐫𝐮 𝐏𝐥𝐚𝐧 lagbe",
#  'pp',
#  'price?',
#  'mayad kotodin',
#  'best service thanks',
#  'price koto',
#  'semrush seo tools er price koto? for 1 month or 3 month.',
#  'semrush কতো?',
#  'no limitations  মানে কি ভাই?  ১মাসের বেশি ব্যবহার করা যাবে semrush 🤔',
#  'price kto bhai?',
#  'vectorizer ai subscription হবে',
#  'price?',
#  'price please?',
#  'canva bade chat gpt plus add kore diben',
#  'price',
#  'price koto',
#  'মাস কত',
#  'price koto? ar  koto diner jonno?',
#  'semrush লাগবে',
#  'দাম',
#  'pp?',
#  'lovely ❣️👍🏻',
#  'grammerly & chatgpt price?',
#  'hello vi, i need adobe creative creative. do you have it?',
#  'turnitin instructor price?',
#  'gravity writer ai nai',
#  'need gravity writer ai',
#  'freepik chatgpt lagbe',
#  'trusted shop❤️',
#  'chatgpt 4 plus  আছে কি? \n1 year koto?',
#  'vidiq',
#  'yes, you provide the best services. best of luck.',
#  'best tools service',
#  'chatgpt,hix,grammarly, canva,semrush,ahref কত টাকা লাগবে',
#  'price',
#  'bhai recraft ai ache naki?',
#  'turnitin price',
#  'price',
#  'hix.ai?',
#  'best service, ma sha allah',
#  'price',
#  'এদের সার্ভিস খুবই ভাল, বিশেষ করে সাপোর্ট সার্ভিস টা খুব ভাল দেন এরা',
#  'অসাধারণ সার্ভিস। \nনক দেবার সাথে সাথে রেসপন্স এবং সমাধান 🥰',
#  'quill bot price?',
#  'price',
#  'price combo pack?',
#  'power bi আছে?',
#  'hix price?',
#  'black friday offer??',
#  'chatgpt, mid-journey, canva pro 1 year lagbe',
#  'so far their service is good. 👍 carry on',
#  'i need some tools',
#  'mid journey koto taka ?',
#  'esob gulo koto?',
#  'এই সবগুলোর প্রাইজ কতো?',
#  'vyond?',
#  'price',
#  'storyblocks image naki video?',
#  'scalenut ar ahrefs আছে',
#  'price koto?',
#  'koto',
#  '3 months',
#  'best service 🐕\u200d🦺',
#  'ahref 1 month koto?',
#  'chatgpt pricd koto',
#  'গুগল স্টোরেজ পাওয়া যাবে?',
#  'chatgpt canva pro lagba',
#  'envato elements lagbe vai...koto porbe??',
#  'need kaggle',
#  'unlimited gmail create korar kuno service ache?',
#  'hix.ai,,,,  grammarly,,,,  turnitn,,,  chatgpt এই চারটি পেকেজ কত টাকা লাগবে।',
#  'need midjourney',
#  'chatgpt and hix ai needed..no shared account. price?',
#  'turninit price?',
#  'শুধু chatgpt premium নিতে চাই',
#  'gpt parice',
#  'happy user \n@followers\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/469130859_425891663927578_6391760748974135731_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=103&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=pqwwomostcaq7knvgeehlc-&_nc_oc=adiv_pj9egdlf1m-hqes7zh4_naokri4m8hbmgtkzeh3cjptdfioat17rt9muruew6c&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=alealtshpp9bpb9_sj-jtxt&oh=00_aydt322nsiros9fruydzcnerpiawlnd-vwnrsvbbj5yatg&oe=67675fd5',
#  'fast response suppprt team.',
#  'storyblocks',
#  'zik analytics hobe?',
#  'quillbot price koto ?',
#  'price koto',
#  'hix bypass price?',
#  'প্রাইজ কত',
#  'price',
#  'hix.ai,,,,  grammarly,,,,  turnitn,,,  chatgpt এই চারটি পেকেজ কত টাকা লাগবে।',
#  'chatgpt, mid-journey 1 month lagbe',
#  'hailuo ai আছে কি',
#  'stealth writer? price',
#  'chatgpt premium price?',
#  'try to best service\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/469491579_428329217017156_6152077393694407338_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=tlfk0wcwin8q7knvgfoxsdi&_nc_oc=adjoenujgshrey7tg1bvuqkpxvjlbanobj0hekptlsf0-l0jb-sl0tsre8nzhudiflk&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=aniz68gqy0i9bzoajozh_kw&oh=00_ayboz9vtfla7qoh724pux7jeu33ycvkcbzai0ef5ztqtna&oe=67676d7f',
#  'price?',
#  'chatgpt-40 1 year price?',
#  'chatgpt packages?',
#  'chat gpt price?',
#  'gpt, semrush, hix ai 3 ta price koto?',
#  'কতদিনের জন্য কত টাকা',
#  'price?',
#  'envato element price?',
#  'price',
#  'mid journey koto?',
#  'price please',
#  'কত',
#  'মেয়াদ কয়দিন',
#  'price inbox',
#  'chat gpt price??',
#  'price?',
#  'midjourney?',
#  'fliki hbe',
#  'price koto?',
#  'price?',
#  'hello vi, i need adobe creative creative. do you have it?',
#  'turnitin instructor price?',
#  'gravity writer ai nai',
#  'need gravity writer ai',
#  'freepik chatgpt lagbe',
#  'trusted shop❤️',
#  'chatgpt 4 plus  আছে কি? \n1 year koto?',
#  'vidiq',
#  'yes, you provide the best services. best of luck.',
#  'best tools service',
#  'chatgpt,hix,grammarly, canva,semrush,ahref কত টাকা লাগবে',
#  'price',
#  'bhai recraft ai ache naki?',
#  'turnitin price',
#  'price',
#  'hix.ai?',
#  'best service, ma sha allah',
#  'price',
#  'এদের সার্ভিস খুবই ভাল, বিশেষ করে সাপোর্ট সার্ভিস টা খুব ভাল দেন এরা',
#  'অসাধারণ সার্ভিস। \nনক দেবার সাথে সাথে রেসপন্স এবং সমাধান 🥰',
#  'quill bot price?',
#  'price',
#  'price combo pack?',
#  'power bi আছে?',
#  'hix price?',
#  'black friday offer??',
#  'chatgpt, mid-journey, canva pro 1 year lagbe',
#  'so far their service is good. 👍 carry on',
#  'i need some tools',
#  'mid journey koto taka ?',
#  'esob gulo koto?',
#  'এই সবগুলোর প্রাইজ কতো?',
#  'vyond?',
#  'price',
#  'storyblocks image naki video?',
#  'scalenut ar ahrefs আছে',
#  'price koto?',
#  'koto',
#  '3 months',
#  'best service 🐕\u200d🦺',
#  'ahref 1 month koto?',
#  'chatgpt pricd koto',
#  'গুগল স্টোরেজ পাওয়া যাবে?',
#  'chatgpt canva pro lagba',
#  'envato elements lagbe vai...koto porbe??',
#  'need kaggle',
#  'unlimited gmail create korar kuno service ache?',
#  'hix.ai,,,,  grammarly,,,,  turnitn,,,  chatgpt এই চারটি পেকেজ কত টাকা লাগবে।',
#  'need midjourney',
#  'chatgpt and hix ai needed..no shared account. price?',
#  'turninit price?',
#  'শুধু chatgpt premium নিতে চাই',
#  'gpt parice',
#  'happy user \n@followers\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/469130859_425891663927578_6391760748974135731_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=103&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=pqwwomostcaq7knvgeehlc-&_nc_oc=adiv_pj9egdlf1m-hqes7zh4_naokri4m8hbmgtkzeh3cjptdfioat17rt9muruew6c&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=apd19lyz19qyzxasj4rn5e5&oh=00_aydz7mlrrodahgfyg4hf1gcb4_wtgszb5kn75ucqbwhvsa&oe=67675fd5',
#  'fast response suppprt team.',
#  'storyblocks',
#  'zik analytics hobe?',
#  'quillbot price koto ?',
#  'price koto',
#  'hix bypass price?',
#  'প্রাইজ কত',
#  'price',
#  'hix.ai,,,,  grammarly,,,,  turnitn,,,  chatgpt এই চারটি পেকেজ কত টাকা লাগবে।',
#  'chatgpt, mid-journey 1 month lagbe',
#  'hailuo ai আছে কি',
#  'stealth writer? price',
#  'chatgpt premium price?',
#  'try to best service\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/469491579_428329217017156_6152077393694407338_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=tlfk0wcwin8q7knvgfoxsdi&_nc_oc=adjoenujgshrey7tg1bvuqkpxvjlbanobj0hekptlsf0-l0jb-sl0tsre8nzhudiflk&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a0d2b1-7puvbug8wjz8x0rv&oh=00_ayccws0vtro_rimlqo0clfc5feqrhupmj6glq0ybkzwpfw&oe=67676d7f',
#  'price?',
#  'chatgpt-40 1 year price?',
#  'chatgpt packages?',
#  'chat gpt price?',
#  'gpt, semrush, hix ai 3 ta price koto?',
#  ...]

# %%
import re
import pandas as pd

# Function to clean text
def clean_text(text):
    # Step 1: Remove emojis
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags
                               u"\U00002500-\U00002BEF"  # Chinese char
                               u"\U00002702-\U000027B0"
                               u"\U0001F926-\U0001F937"
                               u"\U00010000-\U0010FFFF"  # Supplementary characters
                               u"\u200d"                # Zero width joiner
                               u"\u2640-\u2642"         # Female and male symbols
                               u"\u2B50-\u2B55"         # Stars
                               "]+", flags=re.UNICODE)

    text = emoji_pattern.sub(r'', text)  # Remove emojis

    # Step 2: Remove links (URLs)
    text = re.sub(r'https?://\S+|www\.\S+', '', text)

    # Step 3: Remove special characters (keep letters, numbers, spaces)
    text = re.sub(r'[^A-Za-z0-9\s]', '', text)

    # Step 4: Remove extra spaces
    cleaned_text = ' '.join(text.split())

    return cleaned_text

# Apply the clean_text function to 'Content' column
comment_data['Content'] = comment_data['Content'].apply(clean_text)

# Display the cleaned DataFrame
print(comment_data)
# Out:
#                        Author                             Content  \
# 0           Md Minhajul Islam
# 1       Kazi Siratul Mostakim  Brilliant learning app share price
# 2                  Nehal Anas             Lightroom premium price
# 3         Rahmot Hossain Niaz       vi envato elements price koto
# 4                Rehdoy Hasan          wellsaid labs Ai Voice lab
# ...                       ...                                 ...
# 9620  Abu Syed Mohammed Mujib                           Apps Apps
# 9621      Mahadi Ahesan Niloy             I got these under 500Tk
# 9622        Md. Waliul Hasnat   Sobguly lagbe na 34 ta deoua jabe
# 9623                 Arafat A                          NEED kittl
# 9632     Faisaliteb SEO Tools
#
#       SubCommentsCount           CommentAt  DayOfWeek  Hour  WordCount
# 0                  1.0 2024-06-05 14:52:02  Wednesday  14.0          1
# 1                  0.0 2024-06-06 19:39:45   Thursday  19.0          5
# 2                  1.0 2024-06-09 18:40:53     Sunday  18.0          3
# 3                  1.0 2024-06-10 09:53:42     Monday   9.0          5
# 4                  2.0 2024-06-10 10:03:43     Monday  10.0          5
# ...                ...                 ...        ...   ...        ...
# 9620               0.0 2024-12-07 18:30:11   Saturday  18.0         54
# 9621               0.0 2024-12-08 21:22:19     Sunday  21.0          5
# 9622               0.0 2024-12-10 11:14:48    Tuesday  11.0          7
# 9623               0.0 2024-12-10 21:02:31    Tuesday  21.0          2
# 9632               0.0 2024-09-25 06:38:27  Wednesday   6.0          1
#
# [4375 rows x 7 columns]

# %%
list_dataw = []
for data in comment['Content']:
    list_dataw.append(data)

list_dataw
# Out:
# ['কত',
#  'brilliant  learning app share price?',
#  'lightroom premium price?',
#  'vi envato elements price koto?',
#  'wellsaid labs ai voice lab',
#  'need midjurney',
#  'invido ai?',
#  'grammarly price?',
#  'canva lifetime কত টাকা?',
#  'ভিপিএন গুলো প্রিমিয়াম কত দিনের?',
#  'cyberghost vpn sell koren?',
#  'scribd?',
#  'skillshare er price plz',
#  'trial ase ki?',
#  'creative could koto',
#  'scribd',
#  'chatgpt available?',
#  'litcharts available?',
#  'renderforest ase ki',
#  'coursera price?',
#  'spotify and chatgpt plus price please.',
#  'coursera price?',
#  'semrush tool acee?',
#  'chatgpt & udemy premium koto?',
#  'এই সফটওয়্যার গা কি হবে??\n\nhttps://scontent.fdac134-1.fna.fbcdn.net/v/t39.30808-6/450095356_1438945267505239_9112628533560275368_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=bd9a62&_nc_eui2=aefyux2hew6szgndtw6kxksrvl4e6oqrd3xwxgtqhct3fapmypiynatg3feaaygs33iubwnbuyssyuzvyvsuy0lh&_nc_ohc=w65derd575kq7knvghxnuh-&_nc_zt=23&_nc_ht=scontent.fdac134-1.fna&_nc_gid=agpzkcsm2e_lsbjfkw1poap&oh=00_ayb04mroex0dgk1n64tc27vzsub7jlugpmfkev2elb3jkw&oe=673ac6c8',
#  'linkedin?',
#  'vai amar ekta simurelay subscription korte hobe',
#  'coursera price?',
#  'coursera koto kore?',
#  'semrush available?',
#  'cousera and office 365 price?',
#  'how much for working and educational combo',
#  'coursera 1 year koto?',
#  '৩ দিন না হতেই গ্রামারলি সাইন আউট হয়ে গেছে। এখন আর ঢুকতে পারছি না।',
#  'win10+ adobe cloud price?',
#  'zoom premium version available?',
#  'bin number koto?',
#  'udemy koto',
#  'grammarly koto 1 year',
#  'vidiq ase? \n1 year koto',
#  'price',
#  'hix ai koto',
#  'iilevenlabs dite parbn ki?',
#  'vizard.ai hbe ki??',
#  'coursera',
#  'quilbot and turnitin price?',
#  'semrush price',
#  'freepik 1 month koto tk',
#  'adobe xd price?',
#  'freepik ১ মাসের জন্য কতো?',
#  'udemy কত?',
#  'adobe photoshop cc 2024 ase?',
#  'আপনাদের কাছে কি maya & videoscribe এই সফটওয়্যার পাওয়া যাবে?',
#  'zoom meeting?',
#  'canva pro ??',
#  'jenny.ai lagbe',
#  'youtube premium',
#  'udemy price',
#  'picsart available ?',
#  'express for pc. price?',
#  'udemy subscription kto taka.?',
#  'vai a freepik koto',
#  'typeset available?',
#  'coursera?',
#  'spotify?',
#  'idm price koto??',
#  'coursera available?',
#  'koto',
#  'chatgpt koto price?',
#  'udemy koto?',
#  'udemy price?',
#  'elsa speak ase?',
#  'express vpn ache',
#  'idm koto vai',
#  'chatgpt price?',
#  'price chart of all service',
#  'vpn koto??',
#  'idm price?',
#  'coursera+ 1 year price?',
#  'freepik',
#  'just udemy price?',
#  'adobe animated hobe?',
#  'transkriptor',
#  'transkriptor hobe ki',
#  'artgrid lagbay daua jabay?',
#  'coursera?',
#  'vai capcut pro hobe',
#  'microsoft office price please?',
#  'telegram koto?',
#  'creative could koto',
#  'chatgpt and coursera price?',
#  'bandlab premium hobe ki',
#  'adobe koto?',
#  'bandlab premium hobe ki',
#  'flutter with dart programming?',
#  'vpn price?',
#  'https://www.veed.io/\n\nis this available?',
#  '𝘖𝘧𝘧𝘪𝘤𝘦 2021\n𝘐𝘋𝘔 𝘢𝘤𝘵𝘪𝘷𝘦𝘵𝘦𝘥 𝘭𝘪𝘦𝘢𝘯𝘤𝘦 𝘢𝘮𝘪 𝘶𝘴𝘦 𝘬𝘰𝘳𝘪 𝘰𝘯𝘦𝘬 𝘥𝘪𝘯 𝘩𝘰𝘪 𝘬𝘰𝘯 𝘱𝘳𝘰𝘣𝘭𝘦𝘮 𝘯𝘦𝘪.',
#  'canva pro koto',
#  'quilbot achey?',
#  'grammarly koto?',
#  'udemy',
#  'chatgpt ar creative cloud koto ভাইয়া',
#  'udemy price and validation time',
#  'creative cloud koto',
#  'bhai aktu detail bolle valo hoy',
#  'try hack me available?',
#  'elementor koto?',
#  'chatgpt plus price please',
#  'udemy?',
#  'linkedin premium price??',
#  'envato elements price + download per day',
#  'price?',
#  'canva pro koto?',
#  'price',
#  'need some resorses',
#  'coursera?',
#  'turnitin price',
#  'chatgpt 4 premium available? and price?',
#  'qᴜɪʟʙᴏʟᴛ ᴋᴏᴛᴏ',
#  'আইডিএম কত??',
#  'price',
#  'facebook like & followers \nসার্ভিস নিতে চাইলে ইনবক্স করুন',
#  'kittl ai asee?',
#  'wps pro and zoom pro koto',
#  'auto cad electrical  ache?',
#  'vectorizer ai এর subscription হবে',
#  'grammarly koto?',
#  'vy filmora koto onli',
#  'chatgpt',
#  'truecaller?',
#  'chatgpt4 koto?',
#  'artlist.oi hobay?',
#  'chatgpt premium price কত?',
#  'আইফোনের জন্য truecaller premium প্রাইস প্লিজ',
#  'envato hobe?',
#  'chatgpt pricing?',
#  'turintirin 1 month?',
#  'shutterstock ace?',
#  'virbo ai ache?',
#  'price',
#  'in videi ai ase mod apps ba subscription koto',
#  'vid iq koto?',
#  'udemy koto ?',
#  'udemy courses need',
#  'chat gpt koto',
#  'mid journey acche',
#  'adobe creative cloud price koto?',
#  '1. chatgpt plus\n2. zoom\n3. canva\n4. youtube premium\n\ntotal koto?',
#  'window 11 price?',
#  'i need samrash, canva pro, chatgpt premium, quillbot, and grammarly',
#  'udemy koto?',
#  'is gravity write available?',
#  'turnitin instructor acc and hix price?',
#  'gpt price?',
#  'pacdora atar hobe',
#  'freepik kato?',
#  'adobe cc er dam koto?',
#  'midjourney needed',
#  'topview.ai ache?',
#  'grammarly koto?',
#  'istock available..?',
#  'tarnitin',
#  'udemy available??',
#  'relume hobe?',
#  'price koto',
#  'nord vpn price',
#  'duolingo koto?',
#  'adobe creative cloud koto kore',
#  'elementor pro koto',
#  'ellebenlabs available?',
#  'elavenlabs আছে?',
#  'invideo',
#  'invideo ai naki studio?',
#  'coursera plus price',
#  'chat gpt, leonardo, midjourneh dorkar',
#  'chat gpt koto 4.0 all features',
#  'nord vpn price?',
#  'quilbot koto',
#  'udemy access nai',
#  'coursera',
#  'stealth writer add kren',
#  'runway need',
#  'leonardo ai ache?',
#  'socks5 proxy hobe?',
#  'gpt4 needed',
#  'office 24 ase?',
#  'channel crawler ki ace',
#  'freepik primum price koto',
#  'adobe premier ppro pawa jabe ??',
#  'figma possible',
#  'nice',
#  '🥰🥰🥰🥰',
#  'invideo ai monthly kotogulu video make kora jabe abong eleven lab atate adda ase kina',
#  'nice',
#  'নাইস',
#  '🌼🌺❤️\u200d🩹',
#  'coursera price?',
#  'idm price',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465783491_862998889340901_3915706930273420273_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=110&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=qxxoptavgicq7knvgh86xc6&_nc_oc=adir4lgr7whq2pdcmylzoefx3ghs0mrlkejzty1fikd30gh13cq-h5zyem_jwc7zumy&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_ayc83wwvk4p1btdwlgeckluw0ogr-h-ldppettonxyjz4q&oe=67675707',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465756873_862998926007564_7376615731569615050_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=105&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=l5-fh-uymwaq7knvggklcnj&_nc_oc=adhke4se6op_yyrkrcl4b9yiipzw8gqpaz3wdm9aqgncxn3h3xtrbav2fetonw4a53a&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_ayab8j1m_oaxfkegza-ayte57ysxytkrzviqgvd-4auxrw&oe=676785fe',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465889864_862998982674225_5648967310406177799_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=102&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=coz0dvoqolyq7knvgelgdyv&_nc_oc=adhjmc3bsaubtzvkkjxounvtfdanzkmjfrlybvx-m09i1pxkuhn0fvyemjnigta-njc&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_ayaxemzpho_xmk919ny6dh1cy44gucrkhluzbvccgfryyg&oe=67678931',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465859626_862999032674220_5132252421941844461_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=104&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=5h_zbarejwaq7knvge6-ocy&_nc_oc=adg3k-xtawqr2dfifh2qgtbdhq92y9mbqeyv49k4kdzpdfdscuvonegxjpantstlhg4&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_aycorosyz5ftxaef5b_4ehvx97yoqlksonlpkqogiefpiw&oe=67677ef2',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465772130_862999076007549_3576416861749224701_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=104&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=pjcjwalxmo8q7knvgehjxaj&_nc_oc=adhndjeskpfxasigixqi99pfv_nfxodctwc_9ebbszcd4hyieszll3mqmruqhroi2m0&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_aybyrk2xovqzipjpieqtbpq-4kqacuxc6plmpv7tkjn5iq&oe=67675769',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465744613_862999149340875_7195415485991649867_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=110&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=nkzppwniyjwq7knvge8ts7p&_nc_oc=adgliw-nwgcnpqaqncoaey8bx4zshc7xecubwrhozpxmqfmooexkihhn-78ydrqk98k&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_ayacmjep2cvik96o5dir5rsotk2z8vekcxqmxwyvqb8pva&oe=676778c5',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465788613_862999199340870_3309947214393278725_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=103&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=mnmzve8yybiq7knvghm59y9&_nc_oc=adi0qvzt-pfeuwqj47ludcbjp_3dkfvrw-s09skmv-iyy1hchj1hjkc7okusw7yqsne&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_ayaf8nqmsjuydicqm7-7pzcln8gdf3vbz5cjr4izo_rerq&oe=676773db',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465800278_862999249340865_2457650925330434721_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=107&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=qi97cmski3sq7knvgerxiox&_nc_oc=adidm38rbnvvbufswfzepgspckcxgoakyzoxfrubgxvrbfylj4loc57fdfid-qnxqry&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_aycbieg5m9vxv6oz5c2evyuun4wlk21towachvsrluo7bg&oe=67678ae6',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465859872_862999306007526_4506203862991164509_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=100&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=eftgtlmdtqeq7knvghzldre&_nc_oc=adiyk0p7za3sbaocnpr6jgs-ybqq1xmoznxoopwbym4rhcnxkmv3rn3y1w7dt6zezxw&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_aydk-hrsrcfei0o4fdt2idpu_zexl5_zuymzrfmd38eudq&oe=676775eb',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465789308_862999369340853_2906867717378923761_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=111&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=vyfh03ruwgeq7knvggk3qzw&_nc_oc=adj8sipxbdiw7irnsgvmw3n7uwd16_wa1za35pveiau5divvmgh21a6e82c_ijdqwbk&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a-p_nbusa4nkquxw0zjc2fm&oh=00_aybmennz9lvts0_mvs88bopimehpjdtikkbv92ahm0g11g&oe=67677851',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465782292_862999436007513_5681234534562451313_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=110&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=f_vae8znt1aq7knvgfaghu9&_nc_oc=adhkrcj3hlj5bluy3ow8ntqhabfdvknzlrb1nwd5goqahw7fam_mpsyepvwatvrjkow&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_ayabmyyghm4ixfeoh90hfmxgkotsekczs4a9u8rfzljdsa&oe=6767571b',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465789495_862999486007508_9191640361384719464_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=108&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=aecqrff-w_uq7knvgemch77&_nc_oc=adhhi0r8nr8n1jaxafbbdnlrb3qxudyxci4mk1nlj7gyfp_9noj96j_fp85m3eu9ut8&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_aychbgsbxsds_fxzlquq2ntq9heqwey2of29e7lztettxw&oe=6767598e',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465859651_862999522674171_5167425944615470989_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=106&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=monlg6gsy8wq7knvgeuwtzc&_nc_oc=adjtfdrdn1pari4qe9ffw3tiqgk5jnlxkgsdjqvrphghsodb11h26iqm6sy680q_g_0&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_aycchpeq0adejfbx6qzl1atxz2iioyc5n9pxb1z7q-wria&oe=676786d6',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465782093_862999596007497_2148653518807376450_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=5afqkjf33wsq7knvgexptci&_nc_oc=adhyneaw962fbnk90jnf_c3twl8chtn2guvspxbfogl89sfu94b0vaw9psqznwk-cgg&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_aybi2rjltkq1r2f-zv9izpgicjmunxzw_pb6od8lr-ru1a&oe=67677215',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465847352_862999652674158_713988386439032019_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=106&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=kisfrdkkvmkq7knvghyz6-2&_nc_oc=adgftfkv3ei7yhg6lau4ihkoziu2tddiqwi5jcdomjzbat91arvo36_8xi83n2fset8&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_aycv19lfvtvwl2ceyct0pr9jmp2bjmuhkmsnytbvncvbna&oe=676754a9',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465784177_862999722674151_8625913100069975028_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=105&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=acfc6ybaodiq7knvgg3z7wb&_nc_oc=adg7qzlcqcok_th5petvikqb8qubpgi0c_jowglmj3qh3wd8hfj-amnzqfqunxaex6w&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_ayap4ptdm7rkxf0v9kltqtdwzizdgcfb4kd2iuhfhvixig&oe=67676141',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465787143_862999766007480_6617279961171678349_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=111&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=hfhlndafjtgq7knvgeieiv-&_nc_oc=adgbvbrgjf0xerharnqqid4a7ameykhp9xi-dir7lugx4bn7yvuc_crteg0inmfmvhc&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=az21voevspmjuk_ni9jp9ne&oh=00_aybmwestrktleheufcoiwdxgnzfn6yvlw8vpnpe7obyblq&oe=67676287',
#  'smartshort ai',
#  'কিনব',
#  'scalenut আছে',
#  'indexification available??',
#  'helium 10 ache?',
#  'youtube এ ব্যবহৃত  tools কত?',
#  'semrusher shthe kon 3ta gift diben?',
#  'endnote available?',
#  'amar lagbe but complete setup bujie dite hobe',
#  '1 month package  e ki 120+ tools use kora jabe',
#  'leanardo ai price?',
#  '🖤',
#  'md faisal ভাই করলেন ডা কি\U0001fae3\U0001fae3🥰🥰 নিয়া নিলাম।🤭',
#  'backlink indexer tools ase',
#  'daily limit koto',
#  'reza talukder',
#  'daily limit and ki ki feature??  kon panel?',
#  'daily limit for ahref',
#  'ahref, semrush,moz price koto eksonge nile',
#  'kotodin meyad',
#  'leonardo?',
#  '50+ full list dia jabe?',
#  'what is the the daily limit of usage for ahrefs?',
#  'ahrefs a koto credit pabo per day?',
#  'daily limit and ki ki feature??  kon panel?',
#  'price',
#  'daily limit for ahrefs?',
#  'ahrefs eto dam keno?  tools ki ektai?',
#  'stealthwriter ace?',
#  'price?',
#  'really good service',
#  'kivabe pabo?',
#  'semrush price?',
#  'semrush kotho',
#  'good service 👍',
#  'ডেইলি ক্রেডিট লিমিট?',
#  'daily limit koto vai',
#  'semrush,grammerly, canva 3tar package ache?',
#  'i think they provide good services.',
#  'semrush price?',
#  'need it',
#  'ahref, semrush,moz price koto eksonge nile',
#  'we are best and trusted seller 😍\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465838343_407006622482749_3170663742057725845_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=4rdmrrfejweq7knvgho07jf&_nc_oc=adhxgj-qxnb_im2fnjapo9omt1vs1ylioy7pp35o2wffythrp1qxsf5qdjknznnzvsw&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=atxrcfkbj0p89ndry-ozkgy&oh=00_ayaqmlmoqdbku0qufscgnpkzn57_mejc-9mgnshofewtsw&oe=67675c06',
#  'aida kichu hoilo!!! ami niya nilei offer ashe ken😭😭😭???',
#  'aje semrush tool na nelam daki kamon service pai apner akne',
#  'khub vlo service sob somoy vlo e asa korbo vi apnr thaky🖤',
#  'content explore কয়টা করে পাবো?',
#  'envato koto?',
#  'pp',
#  'semrush koto',
#  'turninit price?',
#  'price ?',
#  'yrs',
#  'pp',
#  'yes',
#  'basic youtube seo kaj pari. vidiq nila amr jonno valo hba',
#  'masha allah vai',
#  '❤️🥰',
#  'আমি কিভাবে পেতে পারি?ভাই',
#  'yes',
#  'great',
#  'yes',
#  '❤️❤️❤️',
#  'vidiq+semrush+chatgpt কম্বো হবে?',
#  'kivaby pabo',
#  'best service',
#  'mashallah best service',
#  'mashaallah',
#  '❤️',
#  'ভাই আমার লাগবে',
#  'আমরা যারা কিনি নাই তারা কি ফ্রী পাবো ৫ দিন??',
#  'great service😍',
#  'price? kibabe nibo?',
#  'vidiq 6 month subscription koto?',
#  'price',
#  'pp',
#  'price',
#  'ma sha allah ❤️',
#  'amar lagbe',
#  'vidiq boost and semrush pro plan koto??',
#  'ফয়সাল ভাইয়ের টুলস এর সার্ভিস এক কথায় বলা যায় অসাধারণ এবং ভাইয়ের সাপোর্ট মেম্বারদের কথা তো আর নাই বললাম, রাত তিনটার নয় চারটা নাই যখন এই এসএমএস দিই তখনই তারা আমাদের রেসপন্স করে। \n💘💓💗💖💝💞💞',
#  'price',
#  'hm?',
#  'faisaliteb seo tools check inbox pls',
#  'https://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/449148492_316095051573907_3263288004513382613_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=or1m2jg7oteq7knvghgf4k6&_nc_oc=adhadehmblr4r8yhur969j1zozdxktpz3liokn-_1yfcge2whi0mzpo5zxdmsneos8y&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=adw5nhq5aj1f77cjjm0g9ua&oh=00_ayd9yyjqt5etq9rfjfpque8jbpdrpe1wwdsladauc8p0sg&oe=67675b34',
#  'price?',
#  'price',
#  'vidiq 1 month price',
#  'how much?',
#  'price',
#  'price',
#  '🖤',
#  'md faisal ভাই করলেন ডা কি\U0001fae3\U0001fae3🥰🥰 নিয়া নিলাম।🤭',
#  'backlink indexer tools ase',
#  'daily limit koto',
#  'reza talukder',
#  'daily limit and ki ki feature??  kon panel?',
#  'daily limit for ahref',
#  'ahref, semrush,moz price koto eksonge nile',
#  'kotodin meyad',
#  'leonardo?',
#  '50+ full list dia jabe?',
#  'what is the the daily limit of usage for ahrefs?',
#  'ahrefs a koto credit pabo per day?',
#  'daily limit and ki ki feature??  kon panel?',
#  'price',
#  'daily limit for ahrefs?',
#  'ahrefs eto dam keno?  tools ki ektai?',
#  'stealthwriter ace?',
#  'price?',
#  'really good service',
#  'kivabe pabo?',
#  'semrush price?',
#  'semrush kotho',
#  'good service 👍',
#  'ডেইলি ক্রেডিট লিমিট?',
#  'daily limit koto vai',
#  'semrush,grammerly, canva 3tar package ache?',
#  'i think they provide good services.',
#  'semrush price?',
#  'need it',
#  'ahref, semrush,moz price koto eksonge nile',
#  'we are best and trusted seller 😍\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465838343_407006622482749_3170663742057725845_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=4rdmrrfejweq7knvgho07jf&_nc_oc=adhxgj-qxnb_im2fnjapo9omt1vs1ylioy7pp35o2wffythrp1qxsf5qdjknznnzvsw&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a_ay2w4n3i0rlnl02ipc0wg&oh=00_aycympl8kmhw7qv5mxvwflbwmpvlsv-hjxtwsbagofocjg&oe=67675c06',
#  'aida kichu hoilo!!! ami niya nilei offer ashe ken😭😭😭???',
#  'aje semrush tool na nelam daki kamon service pai apner akne',
#  'khub vlo service sob somoy vlo e asa korbo vi apnr thaky🖤',
#  'content explore কয়টা করে পাবো?',
#  'envato koto?',
#  'pp',
#  'semrush koto',
#  'turninit price?',
#  '🖤',
#  'md faisal ভাই করলেন ডা কি\U0001fae3\U0001fae3🥰🥰 নিয়া নিলাম।🤭',
#  'backlink indexer tools ase',
#  'daily limit koto',
#  'reza talukder',
#  'daily limit and ki ki feature??  kon panel?',
#  'daily limit for ahref',
#  'ahref, semrush,moz price koto eksonge nile',
#  'kotodin meyad',
#  'leonardo?',
#  '50+ full list dia jabe?',
#  'what is the the daily limit of usage for ahrefs?',
#  'ahrefs a koto credit pabo per day?',
#  'daily limit and ki ki feature??  kon panel?',
#  'price',
#  'daily limit for ahrefs?',
#  'ahrefs eto dam keno?  tools ki ektai?',
#  'stealthwriter ace?',
#  'price?',
#  'really good service',
#  'kivabe pabo?',
#  'semrush price?',
#  'semrush kotho',
#  'good service 👍',
#  'ডেইলি ক্রেডিট লিমিট?',
#  'daily limit koto vai',
#  'semrush,grammerly, canva 3tar package ache?',
#  'i think they provide good services.',
#  'semrush price?',
#  'need it',
#  'ahref, semrush,moz price koto eksonge nile',
#  'we are best and trusted seller 😍\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465838343_407006622482749_3170663742057725845_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=4rdmrrfejweq7knvgho07jf&_nc_oc=adhxgj-qxnb_im2fnjapo9omt1vs1ylioy7pp35o2wffythrp1qxsf5qdjknznnzvsw&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=ano3m94_swytda6txkb8ilg&oh=00_aydm07l9e9yeb6mhi60mewryzdob0msnqhan47oborlfda&oe=67675c06',
#  'aida kichu hoilo!!! ami niya nilei offer ashe ken😭😭😭???',
#  'aje semrush tool na nelam daki kamon service pai apner akne',
#  'khub vlo service sob somoy vlo e asa korbo vi apnr thaky🖤',
#  'content explore কয়টা করে পাবো?',
#  'envato koto?',
#  'pp',
#  'semrush koto',
#  'turninit price?',
#  'happy customer\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/465378808_122201882732035191_7978964257109334436_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=103&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=tfvfbu7ayswq7knvgfjy1me&_nc_oc=adirje3gkuilr2e__u-lqiaz9kogd3ac2jyehjck7jt6egnh8ms-xbxince9koxfwfw&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=anka1oiq-icm2xl9amvvjtj&oh=00_aybzzlohpjostxiimdeggsu6ahjwct2q9e05sk08o9bjmw&oe=67677105',
#  'vidiq boost panel ache?',
#  'runwayml ?',
#  'price??  details?',
#  'fliki ai ase?',
#  'netflix, prime video and canva lgbe',
#  'pp details',
#  'amar lagbe',
#  'price?',
#  'sayem ahmed shaon',
#  'chatgpt price',
#  'pp?',
#  'invidio',
#  'reselling koren ?',
#  'lifetime- এলে তো একদিন ও দেন না।- এখন পর্যন্ত কত জন থেকে কিনলাম।',
#  'yearly package ase?',
#  'শুধু ai content writing tool কয়টা যেটা দিয়ে কন্টেন্ট রাইটিং করা যায়???',
#  'ager ad  ekhnkr ad',
#  'demo',
#  'renderforest ase?',
#  'chatgpt আছে?',
#  'vidiq happy customer👑❤️\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/469261843_122204692232035191_2916827757351295562_n.jpg?stp=dst-jpg_p100x100_tt6&_nc_cat=111&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=pkoodmatxugq7knvggmatqu&_nc_oc=adjidgclbcml5aokfiksmwzddp-x7ycz6s8xuehesf0rvmxx8po3ohhfczdj7q02xma&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=agnm2sp5patfrymeoxiemtt&oh=00_ayasklutr25ynlsavdrfsfphlkyz0uufboixpmtgtjswla&oe=67675f5a',
#  'chtgpt koto?',
#  'gpt price',
#  'chatgpt koto?',
#  'chatgpt koto?',
#  'next xtrem টাকা মারার ধোকা সাইট ! কেউ ফাদ পা দিবেন না ! অফার নামে টাকা মেরে দায় ! \nসাবধান !',
#  'cracked?',
#  'vpn ase',
#  'invideo ai v3 চেক করে নেওয়া যাবে?',
#  'vaiya tools lagbe\U0001fae1\U0001fae1',
#  'panel a login er maddhome diben? na sorasori gmail a',
#  'bangla te audio to text converter ase kono?? jodi thake tahole 2/3 ta tools nibo bese bese',
#  '11 labs ace',
#  'vidiq koto?',
#  'invideo.io\ninvideo.studio\nকোনটা দিবেন?',
#  'কতো দিন থাকবে',
#  'elevenlabs er subcription paoya jay ki',
#  'neta chi',
#  'nita cai',
#  'eleven labs',
#  'apnara ki pictory.ai er subscription sell koren?',
#  'pictory subscription hobe?',
#  'ahrefs hobe?',
#  'i want this package.',
#  'semrush koto',
#  'limitations?  activity',
#  'sales navigator nai?',
#  'check inbox',
#  'ahref account koto price',
#  'i need',
#  'semush single r group buy er difference ki ?',
#  'keo nicen eder services?',
#  'seo tools golor keywords research ki daily limitations ace and chat gpt plus ki?',
#  'agula limited  nh unlimited',
#  'নিতে চাই',
#  'nuaim chowdhury',
#  'গ্রুপবাই জিনিস টা আমাকে একটু বুজিয়ে বলাযাবে? আর আমি যদি শুধু সেমরাস কিনতে চাই সেটা কি পারবো? প্রাইজ কত পড়বে',
#  'ঈদের পরে লাগবে ইনশাআল্লাহ',
#  'vidiq premium mobile app hobe',
#  'koto din er jonno',
#  'interested',
#  'semrush kon plan thakba like "pro" "guru" "business" and all tools limitation ta bolban .....',
#  'jasper?',
#  '৬৪০৳ কি কি টুলস পাবো যদি একটু ডিটেইল বলতেন',
#  'all software duration ?',
#  'interested',
#  'chat gpt ase?',
#  'আমার দেখা সেরা  সেলার। যারা চিন্তত আছেন জিতবেন নাকি ঠকবেন তারা নিশ্চিন্তে নিতে পারেন। এনাদের সার্ভিস যেমন ভালো আর সাপোর্টও তেমন ভালো। \n\nas a customer i have 100/100 satisfied',
#  "only e'nvato el'ements koto?",
#  'midjourney alternative kisu ase?',
#  'customer support kemon den seta bolen?',
#  'https://external.fdac7-1.fna.fbcdn.net/emg1/v/t13/16307397131285909973?url=https%3a%2f%2fmedia1.tenor.co%2fimages%2fad92ee75959358d5c8616e2b10c8b6cd%2ftenor.gif%3fc%3dvjffzmfjzwjvb2tfd2viy29tbwvudhm%26itemid%3d22216620&fb_obo=1&utld=tenor.co&stp=dst-jpg_flffffff_q75_s396x396_tt6&_nc_oc=adhs1kwtscvoufoi3c8mhhz_lqrt64lecnrb0no8irho9kzjv6a1fexf5o2dfwsq89w&ccb=13-1&oh=06_q399o2u_fx2jm_3eot1y1ahlacvmdudoty-zx526pzclmzc&oe=67636c14&_nc_sid=867500',
#  'কাজ করে নাকি শুধু একাউন্ট?',
#  'md. abdul khaleque bd',
#  'আসি গতমাসে এক জায়গা থেকে নিয়েছিলাম তার অধিকাংশ অকেজো, প্রো ভার্সন লগইন হয় না, এক কথায় 70% ভূয়া। আবার এই মাসে বেশি টাকা দিয়ে আরেক জায়গা থেকে নিয়েছি একই সমস্যা।',
#  'please kindly inbox me…',
#  'only semrush hobe?',
#  'apnader contain generator best tool kongulo?',
#  'surfer seo ase? cost koto?',
#  '❤️❤️❤️❤️',
#  'offer available now????',
#  'jungle scout available ache?',
#  'undetectable .ai available',
#  'money robot submitter ba rankx hobe?',
#  'এখন কি কোনো অফার আছে??',
#  'chatgpt 4 deya hobe naki',
#  'chat gtp 4 ace ei list e',
#  'i am interested , how can i get.',
#  '640 টাকায় কতো দিনের জন্য??',
#  'shutterstock?',
#  'basic plan a  ami ki tool choose kore nite parbo?',
#  'আমি সব টুল নিবো না সেক্ষেত্রে টাকা কি কম দেওয়া যাবে?',
#  'আপনাদের কাছে কন্টেন রাইটিং এর ভালো টুল কোনটি?',
#  'runway ai tool ache ki?',
#  'ahrefs hobe?',
#  'i want this package.',
#  'semrush koto',
#  'limitations?  activity',
#  'sales navigator nai?',
#  'check inbox',
#  'ahref account koto price',
#  'i need',
#  'semush single r group buy er difference ki ?',
#  'keo nicen eder services?',
#  'seo tools golor keywords research ki daily limitations ace and chat gpt plus ki?',
#  'agula limited  nh unlimited',
#  'নিতে চাই',
#  'nuaim chowdhury',
#  'গ্রুপবাই জিনিস টা আমাকে একটু বুজিয়ে বলাযাবে? আর আমি যদি শুধু সেমরাস কিনতে চাই সেটা কি পারবো? প্রাইজ কত পড়বে',
#  'ঈদের পরে লাগবে ইনশাআল্লাহ',
#  'vidiq premium mobile app hobe',
#  'koto din er jonno',
#  'interested',
#  'semrush kon plan thakba like "pro" "guru" "business" and all tools limitation ta bolban .....',
#  'jasper?',
#  '৬৪০৳ কি কি টুলস পাবো যদি একটু ডিটেইল বলতেন',
#  'all software duration ?',
#  'interested',
#  'chat gpt ase?',
#  'আমার দেখা সেরা  সেলার। যারা চিন্তত আছেন জিতবেন নাকি ঠকবেন তারা নিশ্চিন্তে নিতে পারেন। এনাদের সার্ভিস যেমন ভালো আর সাপোর্টও তেমন ভালো। \n\nas a customer i have 100/100 satisfied',
#  "only e'nvato el'ements koto?",
#  'midjourney alternative kisu ase?',
#  'customer support kemon den seta bolen?',
#  'https://external.fdac7-1.fna.fbcdn.net/emg1/v/t13/16307397131285909973?url=https%3a%2f%2fmedia1.tenor.co%2fimages%2fad92ee75959358d5c8616e2b10c8b6cd%2ftenor.gif%3fc%3dvjffzmfjzwjvb2tfd2viy29tbwvudhm%26itemid%3d22216620&fb_obo=1&utld=tenor.co&stp=dst-jpg_flffffff_q75_s396x396_tt6&_nc_oc=adhs1kwtscvoufoi3c8mhhz_lqrt64lecnrb0no8irho9kzjv6a1fexf5o2dfwsq89w&ccb=13-1&oh=06_q399o2u_fx2jm_3eot1y1ahlacvmdudoty-zx526pzclmzc&oe=67636c14&_nc_sid=867500',
#  'কাজ করে নাকি শুধু একাউন্ট?',
#  'md. abdul khaleque bd',
#  'আসি গতমাসে এক জায়গা থেকে নিয়েছিলাম তার অধিকাংশ অকেজো, প্রো ভার্সন লগইন হয় না, এক কথায় 70% ভূয়া। আবার এই মাসে বেশি টাকা দিয়ে আরেক জায়গা থেকে নিয়েছি একই সমস্যা।',
#  'please kindly inbox me…',
#  'only semrush hobe?',
#  'apnader contain generator best tool kongulo?',
#  'surfer seo ase? cost koto?',
#  '❤️❤️❤️❤️',
#  'offer available now????',
#  'jungle scout available ache?',
#  'undetectable .ai available',
#  'money robot submitter ba rankx hobe?',
#  'এখন কি কোনো অফার আছে??',
#  'chatgpt 4 deya hobe naki',
#  'chat gtp 4 ace ei list e',
#  'i am interested , how can i get.',
#  '640 টাকায় কতো দিনের জন্য??',
#  'shutterstock?',
#  'basic plan a  ami ki tool choose kore nite parbo?',
#  'আমি সব টুল নিবো না সেক্ষেত্রে টাকা কি কম দেওয়া যাবে?',
#  'আপনাদের কাছে কন্টেন রাইটিং এর ভালো টুল কোনটি?',
#  'runway ai tool ache ki?',
#  'writersonic add koren',
#  'kiser kiser web acche',
#  'only semrush kotoh',
#  'sob kichu 850 ?',
#  'vidiq pro acess powa jabe',
#  'semrush  এর লিমিট কত?',
#  'pictory hobe?',
#  'semrush konta diben...?',
#  'quillbot ,surfshark vpn ১ বছরের জন্য কত টাকা ?',
#  'only semrush koto',
#  'ahrefs nai kno??',
#  'play.ht text to voice ai tool ta dorkar. ase kina?',
#  'inbox me',
#  'do you have fliki.ai?',
#  'spy tools ache?',
#  'semrush chai',
#  'semrush er linkd en',
#  'only powtoon hobe ki, hole fee koto?',
#  'pictory ta hobe??',
#  'kotodin er plan bhai?',
#  'kotodin lagbe bhai?',
#  'only semrush ar canva nile kamon porbe?',
#  'kom hole bolben',
#  'rank math ace?',
#  'copy closer tools ki ache?',
#  'service ki valo hoba',
#  'envato elements er cost koto?',
#  'amazon research tools available?',
#  'ফ্রিল্যান্সিং opportunity ⤵️\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/337862139_486983613516856_2493655937544722175_n.jpg?stp=dst-jpg_p75x225_tt6&_nc_cat=109&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=41ilchflqksq7knvghnqfvd&_nc_oc=adg10opvgsrbjaezyrst9j6mp0b4euer9eftxkha8pv6zyh3besltmrgfqg7xt0vpuk&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=aevtczcbp0hpnrx05n9gcof&oh=00_aydywbd7jvvxtq0c1m4n03oesr5ng5twdcifdpunxtn4rq&oe=676786c8',
#  'f',
#  'yoast seo?',
#  'ahrefs tools available',
#  'gramarly, word ai,woo rank 6 months koto porbe',
#  'how',
#  'åhøshàñ hâßïß ríyåd',
#  'only semrush.\nmonthly or what other type subscriptions?',
#  'murf ai?',
#  'semrush & article builder\nprice',
#  'murf',
#  "$emr**sh (সেম রাশ),keyword r'evealer (bonus) ki premium",
#  'কন্টেন্ট রাইটিং এর টুলস আছে আপনার কাছে',
#  'ahrefs+ semruch koto?',
#  'jasper আছে কি',
#  'hi',
#  'article writing er jonno konta ace',
#  'only need moz premium',
#  'chat gpt plus available?',
#  'please inbox in details...',
#  'lead generation er tools hobe???',
#  'semrush hobe bhaia?',
#  'vidiq koto',
#  'give me basic plan details?',
#  '❤️',
#  'standard plan - 35+ tools - 500 takai deya jabe  tk',
#  'blog cutter ,jasper, smodin hobe ki',
#  'writersonic add koren',
#  'kiser kiser web acche',
#  'only semrush kotoh',
#  'sob kichu 850 ?',
#  'vidiq pro acess powa jabe',
#  'semrush  এর লিমিট কত?',
#  'pictory hobe?',
#  'semrush konta diben...?',
#  'quillbot ,surfshark vpn ১ বছরের জন্য কত টাকা ?',
#  'only semrush koto',
#  'ahrefs nai kno??',
#  'play.ht text to voice ai tool ta dorkar. ase kina?',
#  'inbox me',
#  'do you have fliki.ai?',
#  'spy tools ache?',
#  'semrush chai',
#  'semrush er linkd en',
#  'only powtoon hobe ki, hole fee koto?',
#  'pictory ta hobe??',
#  'kotodin er plan bhai?',
#  'kotodin lagbe bhai?',
#  'only semrush ar canva nile kamon porbe?',
#  'kom hole bolben',
#  'rank math ace?',
#  'copy closer tools ki ache?',
#  'service ki valo hoba',
#  'envato elements er cost koto?',
#  'amazon research tools available?',
#  'ফ্রিল্যান্সিং opportunity ⤵️\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/337862139_486983613516856_2493655937544722175_n.jpg?stp=dst-jpg_p75x225_tt6&_nc_cat=109&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=41ilchflqksq7knvghnqfvd&_nc_oc=adg10opvgsrbjaezyrst9j6mp0b4euer9eftxkha8pv6zyh3besltmrgfqg7xt0vpuk&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=amrst-zupey2oe-el-sr3um&oh=00_aydej43nn0cmslvasbhkjbovbecfrrorigc5vx3uqwgqhg&oe=67674e88',
#  'f',
#  'yoast seo?',
#  'ahrefs tools available',
#  'gramarly, word ai,woo rank 6 months koto porbe',
#  'how',
#  'åhøshàñ hâßïß ríyåd',
#  'only semrush.\nmonthly or what other type subscriptions?',
#  'murf ai?',
#  'semrush & article builder\nprice',
#  'murf',
#  "$emr**sh (সেম রাশ),keyword r'evealer (bonus) ki premium",
#  'কন্টেন্ট রাইটিং এর টুলস আছে আপনার কাছে',
#  'ahrefs+ semruch koto?',
#  'jasper আছে কি',
#  'hi',
#  'article writing er jonno konta ace',
#  'only need moz premium',
#  'chat gpt plus available?',
#  'please inbox in details...',
#  'lead generation er tools hobe???',
#  'semrush hobe bhaia?',
#  'vidiq koto',
#  'give me basic plan details?',
#  '❤️',
#  'standard plan - 35+ tools - 500 takai deya jabe  tk',
#  'blog cutter ,jasper, smodin hobe ki',
#  'alhamdulillah, i received a lot of good service from the brothers',
#  'nord vpn account\n১ বছরের মেয়াদে কম দামে সেল দেওয়া হবে।\nজিমেইল পাসওয়ার্ড সহ দিয়ে দেওয়া হবে।\nলাগলে ইনবক্স।।।',
#  'nord vpn  6month',
#  'cyber ghost  koto',
#  'nord koto',
#  'express vpn',
#  'surf shark koto',
#  'ip vanish koto',
#  'https://social-earn.top/509054744791',
#  'ip vanish koto',
#  'they are great in service pls keep up',
#  'nord price',
#  'lifetime access pabo??',
#  'আমাদের কাছে রয়েছে chat gpt সহ আরো অনেক জনপ্রিয় টুলস তাই এখনি ভিজিট করুন  আপনার পচ্ছন্দের টুলস buy করতে :-  https://faisalitebtools.com/',
#  '🔥 buy now and instant access visit : https://faisalitebtools.com/\nand we are trusted seller',
#  'সাথে আরো কিছু দিলে ভাল হইত \U0001fae3',
#  'সবকিছু বললেন কিন্তু প্রাইস বললেন না এটা হলো?',
#  '6 manth koto',
#  'price?',
#  'price koto?',
#  'faisaliteb seo tools bhaijan 1 monther jonno price koto..?\nchatgpt nile alada koto lagbe?',
#  'vi r kisu ni',
#  'price?',
#  '#freelancingschoolbdbyrifat\nhttps://youtu.be/lqpk8vwhjuo?si=eqvn232cc8a5ggs9',
#  'one month price',
#  '1year price',
#  'p',
#  'price??',
#  'price koto?',
#  'আপনাদের সার্ভিস টা আসলেই অনেক ভালো \nএরকম সার্ভিস কন্টিনিউ থাকলে আর অন্য কোথাও থেকে কিনতে হবে না',
#  'hello',
#  'price',
#  'grammerly koto',
#  'price',
#  'ekhane ki backlink possible..? r backlink korle index hoar possiblity koto toku...?',
#  'semrush seo tools er price koto? for 1 month or 3 month.',
#  'আমার শুধু semrush লাগবে কত টাকা লাগবে বলবেন প্লিজ',
#  '6 month koto?',
#  'price?',
#  'price?',
#  'price',
#  'prize koto vai?',
#  'price',
#  'আপনাদের সার্ভিস আমার ব্যক্তিগত ভাবে অনেক ভালো লাগছে। আপনাদের টিম মেম্বারদের অমায়িক আচরণ দেখে আমি মুগ্ধ। আসা করি এইভাবে আপনাদের সফলতা অনেক দূর এগিয়ে নিয়ে যাবেন 😘❤️',
#  'ekhon ki ai tools nite parbo?',
#  'ptice',
#  'price',
#  'best tools service ❤️',
#  'lifetime',
#  'canva pro koto',
#  "𝐒𝐄𝐌'𝐫𝐮𝐬𝐡 𝐆𝐮𝐫𝐮 𝐏𝐥𝐚𝐧 lagbe",
#  'pp',
#  'price?',
#  'mayad kotodin',
#  'best service thanks',
#  'price koto',
#  'semrush seo tools er price koto? for 1 month or 3 month.',
#  'semrush কতো?',
#  'no limitations  মানে কি ভাই?  ১মাসের বেশি ব্যবহার করা যাবে semrush 🤔',
#  'price kto bhai?',
#  'vectorizer ai subscription হবে',
#  'price?',
#  'price please?',
#  'canva bade chat gpt plus add kore diben',
#  'price',
#  'price koto',
#  'মাস কত',
#  'price koto? ar  koto diner jonno?',
#  'semrush লাগবে',
#  'দাম',
#  'pp?',
#  'lovely ❣️👍🏻',
#  'grammerly & chatgpt price?',
#  'price',
#  'price please sir',
#  'price',
#  'price?',
#  'price?',
#  'স্যার ডিস্কাউন্ট দেবেন না?😌',
#  'koto din?',
#  'limitation?',
#  'details please',
#  '30 din por abar access cole jabe?',
#  'interested',
#  'service kemon?',
#  'lifelife membership ase ki',
#  'details please',
#  'ahrefs tool nai',
#  'কত দিনের জন্য?',
#  'have your others tools?',
#  'price',
#  'interested',
#  'details please',
#  'আমি বুঝিনা এটা, $120 ডলার বা ১২০০০ পার মান্থ এর একটা টুলস আপনারা কিভাবে ৩৯৯ টাকায় দেন!',
#  'কোনো লিমিটেশন আছে?',
#  'vaiya ota ki 1 month limit nki',
#  'koto diner jonno eita',
#  'ata ki monthly service',
#  'koto gula site audit kora jabe',
#  'ahrefs den?',
#  'details \nplease',
#  'details plz',
#  'available guru plan',
#  'details please',
#  'details please',
#  '399 tk ki 1 month warranty',
#  'i need discount',
#  'এনাদের সার্ভিস অনেক ভাল আজকেই নিলাম এডমিন ভাইয়ের বিহেভিয়ার ভাল ছিল, আশা করি ইউজার এক্সপেরিয়েন্স ভাল হবে 🙂',
#  'kivabe use korbo',
#  'price??',
#  'with site audit feature?',
#  'details please.',
#  'details please',
#  '399tk=koto months',
#  'monthly 399?',
#  'aherfs',
#  'kebol semrush + moze kinlam. \n\nquick and helpful\n\napnra o kinte paren',
#  '399 takay 1 month???',
#  '1 weak er jonno nite chai',
#  'interested',
#  'সব ফিচার পাওয়া যাবে? কয়টা প্রোজেক্ট অ্যাড করা যাবে? টক্সিক লিংক রিমুভ সহ সব ধরবের এরর আর ওয়ারনিং দেখাবে? আর সব চেয়ে ইম্পরট্যান্ট মাস শেষে নতুন করে রিনিউবকরা পসিবল কিনা?',
#  'access kiser madhome diya hoy?',
#  'details please',
#  'details plz',
#  'লাইফটাইম প্লান কত?',
#  'মেয়াদ?',
#  'ahrefs available?',
#  'এই অফার কতদিন চলবে?',
#  'ai ta ki sharing ?',
#  'details pls',
#  'project add koyta kora jay?',
#  'koto din',
#  'do u have ahrefs?',
#  'available?',
#  'lifetime access pabo??',
#  'আমাদের কাছে রয়েছে chat gpt সহ আরো অনেক জনপ্রিয় টুলস তাই এখনি ভিজিট করুন  আপনার পচ্ছন্দের টুলস buy করতে :-  https://faisalitebtools.com/',
#  '🔥 buy now and instant access visit : https://faisalitebtools.com/\nand we are trusted seller',
#  'সাথে আরো কিছু দিলে ভাল হইত \U0001fae3',
#  'সবকিছু বললেন কিন্তু প্রাইস বললেন না এটা হলো?',
#  '6 manth koto',
#  'price?',
#  'price koto?',
#  'faisaliteb seo tools bhaijan 1 monther jonno price koto..?\nchatgpt nile alada koto lagbe?',
#  'vi r kisu ni',
#  'price?',
#  '#freelancingschoolbdbyrifat\nhttps://youtu.be/lqpk8vwhjuo?si=eqvn232cc8a5ggs9',
#  'one month price',
#  '1year price',
#  'p',
#  'price??',
#  'price koto?',
#  'আপনাদের সার্ভিস টা আসলেই অনেক ভালো \nএরকম সার্ভিস কন্টিনিউ থাকলে আর অন্য কোথাও থেকে কিনতে হবে না',
#  'hello',
#  'price',
#  'grammerly koto',
#  'price',
#  'ekhane ki backlink possible..? r backlink korle index hoar possiblity koto toku...?',
#  'semrush seo tools er price koto? for 1 month or 3 month.',
#  'আমার শুধু semrush লাগবে কত টাকা লাগবে বলবেন প্লিজ',
#  '6 month koto?',
#  'price?',
#  'price?',
#  'price',
#  'prize koto vai?',
#  'price',
#  'আপনাদের সার্ভিস আমার ব্যক্তিগত ভাবে অনেক ভালো লাগছে। আপনাদের টিম মেম্বারদের অমায়িক আচরণ দেখে আমি মুগ্ধ। আসা করি এইভাবে আপনাদের সফলতা অনেক দূর এগিয়ে নিয়ে যাবেন 😘❤️',
#  'ekhon ki ai tools nite parbo?',
#  'ptice',
#  'price',
#  'best tools service ❤️',
#  'lifetime',
#  'canva pro koto',
#  "𝐒𝐄𝐌'𝐫𝐮𝐬𝐡 𝐆𝐮𝐫𝐮 𝐏𝐥𝐚𝐧 lagbe",
#  'pp',
#  'price?',
#  'mayad kotodin',
#  'best service thanks',
#  'price koto',
#  'semrush seo tools er price koto? for 1 month or 3 month.',
#  'semrush কতো?',
#  'no limitations  মানে কি ভাই?  ১মাসের বেশি ব্যবহার করা যাবে semrush 🤔',
#  'price kto bhai?',
#  'vectorizer ai subscription হবে',
#  'price?',
#  'price please?',
#  'canva bade chat gpt plus add kore diben',
#  'price',
#  'price koto',
#  'মাস কত',
#  'price koto? ar  koto diner jonno?',
#  'semrush লাগবে',
#  'দাম',
#  'pp?',
#  'lovely ❣️👍🏻',
#  'grammerly & chatgpt price?',
#  'hello vi, i need adobe creative creative. do you have it?',
#  'turnitin instructor price?',
#  'gravity writer ai nai',
#  'need gravity writer ai',
#  'freepik chatgpt lagbe',
#  'trusted shop❤️',
#  'chatgpt 4 plus  আছে কি? \n1 year koto?',
#  'vidiq',
#  'yes, you provide the best services. best of luck.',
#  'best tools service',
#  'chatgpt,hix,grammarly, canva,semrush,ahref কত টাকা লাগবে',
#  'price',
#  'bhai recraft ai ache naki?',
#  'turnitin price',
#  'price',
#  'hix.ai?',
#  'best service, ma sha allah',
#  'price',
#  'এদের সার্ভিস খুবই ভাল, বিশেষ করে সাপোর্ট সার্ভিস টা খুব ভাল দেন এরা',
#  'অসাধারণ সার্ভিস। \nনক দেবার সাথে সাথে রেসপন্স এবং সমাধান 🥰',
#  'quill bot price?',
#  'price',
#  'price combo pack?',
#  'power bi আছে?',
#  'hix price?',
#  'black friday offer??',
#  'chatgpt, mid-journey, canva pro 1 year lagbe',
#  'so far their service is good. 👍 carry on',
#  'i need some tools',
#  'mid journey koto taka ?',
#  'esob gulo koto?',
#  'এই সবগুলোর প্রাইজ কতো?',
#  'vyond?',
#  'price',
#  'storyblocks image naki video?',
#  'scalenut ar ahrefs আছে',
#  'price koto?',
#  'koto',
#  '3 months',
#  'best service 🐕\u200d🦺',
#  'ahref 1 month koto?',
#  'chatgpt pricd koto',
#  'গুগল স্টোরেজ পাওয়া যাবে?',
#  'chatgpt canva pro lagba',
#  'envato elements lagbe vai...koto porbe??',
#  'need kaggle',
#  'unlimited gmail create korar kuno service ache?',
#  'hix.ai,,,,  grammarly,,,,  turnitn,,,  chatgpt এই চারটি পেকেজ কত টাকা লাগবে।',
#  'need midjourney',
#  'chatgpt and hix ai needed..no shared account. price?',
#  'turninit price?',
#  'শুধু chatgpt premium নিতে চাই',
#  'gpt parice',
#  'happy user \n@followers\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/469130859_425891663927578_6391760748974135731_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=103&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=pqwwomostcaq7knvgeehlc-&_nc_oc=adiv_pj9egdlf1m-hqes7zh4_naokri4m8hbmgtkzeh3cjptdfioat17rt9muruew6c&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=alealtshpp9bpb9_sj-jtxt&oh=00_aydt322nsiros9fruydzcnerpiawlnd-vwnrsvbbj5yatg&oe=67675fd5',
#  'fast response suppprt team.',
#  'storyblocks',
#  'zik analytics hobe?',
#  'quillbot price koto ?',
#  'price koto',
#  'hix bypass price?',
#  'প্রাইজ কত',
#  'price',
#  'hix.ai,,,,  grammarly,,,,  turnitn,,,  chatgpt এই চারটি পেকেজ কত টাকা লাগবে।',
#  'chatgpt, mid-journey 1 month lagbe',
#  'hailuo ai আছে কি',
#  'stealth writer? price',
#  'chatgpt premium price?',
#  'try to best service\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/469491579_428329217017156_6152077393694407338_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=tlfk0wcwin8q7knvgfoxsdi&_nc_oc=adjoenujgshrey7tg1bvuqkpxvjlbanobj0hekptlsf0-l0jb-sl0tsre8nzhudiflk&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=aniz68gqy0i9bzoajozh_kw&oh=00_ayboz9vtfla7qoh724pux7jeu33ycvkcbzai0ef5ztqtna&oe=67676d7f',
#  'price?',
#  'chatgpt-40 1 year price?',
#  'chatgpt packages?',
#  'chat gpt price?',
#  'gpt, semrush, hix ai 3 ta price koto?',
#  'কতদিনের জন্য কত টাকা',
#  'price?',
#  'envato element price?',
#  'price',
#  'mid journey koto?',
#  'price please',
#  'কত',
#  'মেয়াদ কয়দিন',
#  'price inbox',
#  'chat gpt price??',
#  'price?',
#  'midjourney?',
#  'fliki hbe',
#  'price koto?',
#  'price?',
#  'hello vi, i need adobe creative creative. do you have it?',
#  'turnitin instructor price?',
#  'gravity writer ai nai',
#  'need gravity writer ai',
#  'freepik chatgpt lagbe',
#  'trusted shop❤️',
#  'chatgpt 4 plus  আছে কি? \n1 year koto?',
#  'vidiq',
#  'yes, you provide the best services. best of luck.',
#  'best tools service',
#  'chatgpt,hix,grammarly, canva,semrush,ahref কত টাকা লাগবে',
#  'price',
#  'bhai recraft ai ache naki?',
#  'turnitin price',
#  'price',
#  'hix.ai?',
#  'best service, ma sha allah',
#  'price',
#  'এদের সার্ভিস খুবই ভাল, বিশেষ করে সাপোর্ট সার্ভিস টা খুব ভাল দেন এরা',
#  'অসাধারণ সার্ভিস। \nনক দেবার সাথে সাথে রেসপন্স এবং সমাধান 🥰',
#  'quill bot price?',
#  'price',
#  'price combo pack?',
#  'power bi আছে?',
#  'hix price?',
#  'black friday offer??',
#  'chatgpt, mid-journey, canva pro 1 year lagbe',
#  'so far their service is good. 👍 carry on',
#  'i need some tools',
#  'mid journey koto taka ?',
#  'esob gulo koto?',
#  'এই সবগুলোর প্রাইজ কতো?',
#  'vyond?',
#  'price',
#  'storyblocks image naki video?',
#  'scalenut ar ahrefs আছে',
#  'price koto?',
#  'koto',
#  '3 months',
#  'best service 🐕\u200d🦺',
#  'ahref 1 month koto?',
#  'chatgpt pricd koto',
#  'গুগল স্টোরেজ পাওয়া যাবে?',
#  'chatgpt canva pro lagba',
#  'envato elements lagbe vai...koto porbe??',
#  'need kaggle',
#  'unlimited gmail create korar kuno service ache?',
#  'hix.ai,,,,  grammarly,,,,  turnitn,,,  chatgpt এই চারটি পেকেজ কত টাকা লাগবে।',
#  'need midjourney',
#  'chatgpt and hix ai needed..no shared account. price?',
#  'turninit price?',
#  'শুধু chatgpt premium নিতে চাই',
#  'gpt parice',
#  'happy user \n@followers\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/469130859_425891663927578_6391760748974135731_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=103&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=pqwwomostcaq7knvgeehlc-&_nc_oc=adiv_pj9egdlf1m-hqes7zh4_naokri4m8hbmgtkzeh3cjptdfioat17rt9muruew6c&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=apd19lyz19qyzxasj4rn5e5&oh=00_aydz7mlrrodahgfyg4hf1gcb4_wtgszb5kn75ucqbwhvsa&oe=67675fd5',
#  'fast response suppprt team.',
#  'storyblocks',
#  'zik analytics hobe?',
#  'quillbot price koto ?',
#  'price koto',
#  'hix bypass price?',
#  'প্রাইজ কত',
#  'price',
#  'hix.ai,,,,  grammarly,,,,  turnitn,,,  chatgpt এই চারটি পেকেজ কত টাকা লাগবে।',
#  'chatgpt, mid-journey 1 month lagbe',
#  'hailuo ai আছে কি',
#  'stealth writer? price',
#  'chatgpt premium price?',
#  'try to best service\n\nhttps://scontent.fdac7-1.fna.fbcdn.net/v/t39.30808-6/469491579_428329217017156_6152077393694407338_n.jpg?stp=dst-jpg_s261x260_tt6&_nc_cat=101&ccb=1-7&_nc_sid=bd9a62&_nc_ohc=tlfk0wcwin8q7knvgfoxsdi&_nc_oc=adjoenujgshrey7tg1bvuqkpxvjlbanobj0hekptlsf0-l0jb-sl0tsre8nzhudiflk&_nc_zt=23&_nc_ht=scontent.fdac7-1.fna&_nc_gid=a0d2b1-7puvbug8wjz8x0rv&oh=00_ayccws0vtro_rimlqo0clfc5feqrhupmj6glq0ybkzwpfw&oe=67676d7f',
#  'price?',
#  'chatgpt-40 1 year price?',
#  'chatgpt packages?',
#  'chat gpt price?',
#  'gpt, semrush, hix ai 3 ta price koto?',
#  ...]

# %%
import re
from collections import Counter



# Regular expression to extract tools and software names (customize as needed)
pattern = r'\b[A-Z][a-zA-Z0-9\+]+\b'

# Extract all matches
all_tools = []
for comment in comment_data['Content']:
    matches = re.findall(pattern, comment)
    all_tools.extend(matches)

# Count the occurrences
tool_counts = Counter(all_tools)

# Display results
print("Tool/Software Usage Count:")
for tool, count in tool_counts.most_common():
    print(f"{tool}: {count}")
# Out:
# Tool/Software Usage Count:
# Price: 653
# Semrush: 199
# Koto: 62
# Chatgpt: 56
# Ahrefs: 54
# Canva: 49
# Envato: 41
# Chat: 36
# Leonardo: 36
# Vai: 35
# Ahref: 34
# Service: 34
# Midjourney: 33
# Details: 33
# Mid: 33
# Only: 32
# Ami: 32
# How: 31
# Pp: 31
# Interested: 31
# Tools: 30
# Ahrefsgroupbuy: 30
# SEO: 29
# Adobe: 28
# Best: 28
# Need: 25
# SEMRUSH: 25
# Pro: 24
# Invideo: 23
# Vidiq: 23
# Ai: 22
# Grammarly: 22
# ChatGPT: 21
# Coursera: 20
# Good: 20
# Jasper: 20
# AI: 19
# Please: 19
# Freepik: 17
# Thanks: 17
# SEMrush: 16
# Udemy: 15
# Hix: 14
# Premium: 14
# Hobe: 14
# Inbox: 14
# Very: 14
# Turnitin: 13
# Amar: 13
# Great: 13
# Faisaliteb: 13
# GPT: 12
# Buy: 12
# Google: 12
# Nice: 11
# Monthly: 10
# Prices: 10
# Dam: 10
# Windows: 10
# Bhai: 9
# Lifetime: 9
# Do: 9
# Moz: 9
# Trusted: 9
# Unlimited: 9
# Ubersuggest: 9
# Package: 9
# Link: 9
# CANVA: 9
# VidIQ: 8
# Available: 8
# In: 8
# Youtube: 8
# Hello: 8
# Prize: 8
# Apnader: 8
# Sem: 8
# Highly: 8
# PRO: 8
# LinkedIn: 7
# Express: 7
# IDM: 7
# Is: 7
# Facebook: 7
# Nord: 7
# Daily: 7
# Gpt: 7
# Pictory: 7
# Hi: 7
# Grammerly: 7
# Recraft: 7
# Life: 7
# Im: 7
# Seo: 7
# Thank: 7
# Muhammad: 7
# Office: 7
# Zoom: 6
# Vpn: 6
# Just: 6
# Telegram: 6
# Valo: 6
# Md: 6
# Really: 6
# Netflix: 6
# Elevenlabs: 6
# Surfer: 6
# Offer: 6
# Access: 6
# Lagbe: 6
# Gravity: 6
# Video: 6
# Hixai: 6
# Free: 6
# ChatGPT4: 6
# Ki: 6
# Meyad: 6
# Quilbot: 5
# Creative: 5
# Runway: 5
# What: 5
# Khub: 5
# Yes: 5
# Allah: 5
# Happy: 5
# Eleven: 5
# Alhamdulillah: 5
# Now: 5
# Instant: 5
# Ata: 5
# Image: 5
# Ar: 5
# Share: 5
# Hasan: 5
# Nite: 5
# Active: 5
# Tik: 5
# Writing: 5
# Can: 5
# Bangladesh: 5
# Photoshop: 5
# Student: 5
# Microsoft: 4
# Shutterstock: 4
# Vid: 4
# Kato: 4
# Helium: 4
# Kon: 4
# Fliki: 4
# Vaiya: 4
# Invideoio: 4
# Guru: 4
# Bd: 4
# Cost: 4
# SEMRush: 4
# Keyword: 4
# Standard: 4
# Plan: 4
# They: 4
# Visit: 4
# Quick: 4
# Vyond: 4
# User: 4
# Korte: 4
# Any: 4
# Support: 4
# Single: 4
# Combo: 4
# Plesse: 4
# Islam: 4
# Recommended: 4
# Midjourny: 4
# It: 4
# Journey: 4
# Gmail: 4
# Tok: 4
# Chegg: 4
# Gravitywrite: 4
# Kono: 4
# Log: 4
# Seowriting: 4
# Heygen: 4
# Chagpt: 4
# Autocad: 4
# Text: 4
# Dall: 4
# Vibiq: 4
# Chatgtp: 4
# Send: 4
# Months: 4
# Tk: 4
# Invido: 3
# Bin: 3
# Year: 3
# PicsArt: 3
# Idm: 3
# Bandlab: 3
# VPN: 3
# Linkedin: 3
# And: 3
# Artlistoi: 3
# Virbo: 3
# Total: 3
# Duolingo: 3
# Scalenut: 3
# Kotodin: 3
# Full: 3
# Stealthwriter: 3
# We: 3
# Basic: 3
# Jodi: 3
# Sales: 3
# Chowdhury: 3
# Duration: 3
# SemRush: 3
# Jungle: 3
# Ase: 3
# Lead: 3
# Seller: 3
# ChatGpt: 3
# Nile: 3
# For: 3
# HixAi: 3
# Friday: 3
# Response: 3
# Team: 3
# Awesome: 3
# Their: 3
# Ei: 3
# Eta: 3
# Group: 3
# Excellent: 3
# Semeush: 3
# Samrush: 3
# One: 3
# MD: 3
# Up: 3
# Ideogram: 3
# Instagram: 3
# Froms: 3
# Check: 3
# Super: 3
# Got: 3
# Drive: 3
# Topviewai: 3
# Aita: 3
# Semrus: 3
# Mobile: 3
# PRICE: 3
# Rana: 3
# Farhan: 3
# Khan: 3
# Time: 3
# Trends: 3
# Scribd: 2
# Renderforest: 2
# Spotify: 2
# Working: 2
# YouTube: 2
# Transkriptor: 2
# ArtGrid: 2
# Elements: 2
# Truecaller: 2
# Chatgpt4: 2
# Quillbot: 2
# Istock: 2
# Ellebenlabs: 2
# Elavenlabs: 2
# Stealth: 2
# Faisal: 2
# Backlink: 2
# Eto: 2
# Ace: 2
# Kivabe: 2
# Turninit: 2
# Kibabe: 2
# Ma: 2
# Sha: 2
# Shaon: 2
# Yearly: 2
# Demo: 2
# Apnara: 2
# Limitations: 2
# Undetectable: 2
# Kom: 2
# Amazon: 2
# Opportunity: 2
# TK: 2
# Ip: 2
# Jonno: 2
# Alada: 2
# Vi: 2
# Limitation: 2
# Quill: 2
# Black: 2
# So: 2
# Storyblocks: 2
# Shared: 2
# Bot: 2
# React: 2
# All: 2
# Recommend: 2
# Wordtune: 2
# Provider: 2
# Customize: 2
# Singnalhare: 2
# Vidnoz: 2
# Lite: 2
# Keepa: 2
# Ubbersuggest: 2
# Buzzsumo: 2
# Services: 2
# Annual: 2
# Dubdup: 2
# Bro: 2
# Id: 2
# Sir: 2
# Er: 2
# Experience: 2
# Jarvis: 2
# SEM: 2
# Rush: 2
# Product: 2
# VidiQ: 2
# Kot: 2
# The: 2
# KOTO: 2
# Shudhu: 2
# Invedio: 2
# Deelisco: 2
# Validity: 2
# Bangladeshi: 2
# Instragram: 2
# Tiktok: 2
# Hot: 2
# Whatsapp: 2
# BD: 2
# Figma: 2
# TRX: 2
# Hope: 2
# Hoichoi: 2
# SemrushquetextNetflix: 2
# Script: 2
# Grammerely: 2
# Leanardo: 2
# Seowriterai: 2
# Already: 2
# Almost: 2
# Sathe: 2
# VidIQCanva: 2
# Explain: 2
# But: 2
# Koyekbar: 2
# Dashboard: 2
# Packeg: 2
# BusinessPlease: 2
# Amake: 2
# Content: 2
# Domain: 2
# Mahmudul: 2
# Rifat: 2
# Month: 2
# Veyond: 2
# Invdo: 2
# Digital: 2
# Jabe: 2
# Ecoomerce: 2
# Invox: 2
# Bitik: 2
# Baaz: 2
# Capcut: 2
# Placeit: 2
# Epidemic: 2
# EaseUS: 2
# Data: 2
# Recovery: 2
# Software: 2
# Qulibot: 2
# Vecteezy: 2
# Adobir: 2
# Harvard: 2
# MIT: 2
# LBS: 2
# Maxon: 2
# Niloy: 2
# Ghosh: 2
# Dwip: 2
# Lr: 2
# Version: 2
# Piz: 2
# Canvas: 2
# Cloth: 2
# Ms: 2
# API: 2
# Official: 2
# Chate: 2
# Subscriptions: 2
# Copailot: 2
# CHAT: 2
# E3: 2
# DallE: 2
# Assalamualaikum: 2
# Plz: 2
# Sidekick: 2
# Minibot: 2
# Airdrop: 2
# Binance: 2
# Extra: 2
# Raise: 2
# Them: 2
# Physics: 2
# Tech: 2
# Tayyaba: 2
# Trader: 2
# Ashref: 2
# Haswan: 2
# Christan: 2
# Kindly: 2
# If: 2
# Click: 2
# VidIq: 2
# Perplexity: 2
# Interest: 2
# Graphic: 2
# List: 2
# Your: 2
# Like: 2
# Wow: 2
# Limit: 2
# Limited: 2
# Masallah: 2
# Email: 2
# THE: 2
# Apps: 2
# Brilliant: 1
# Lightroom: 1
# Voice: 1
# CyberGhost: 1
# Skillshare: 1
# Trial: 1
# Litcharts: 1
# Cousera: 1
# Vizardai: 1
# Xd: 1
# Meeting: 1
# Jennyai: 1
# PC: 1
# Elsa: 1
# Flutter: 1
# Dart: 1
# Hoy: 1
# Try: 1
# Elementor: 1
# Download: 1
# WPS: 1
# Auto: 1
# Filmora: 1
# Turintirin: 1
# Iq: 1
# Plus: 1
# Window: 1
# Tarnitin: 1
# Relume: 1
# Cloud: 1
# Gpt4: 1
# Channel: 1
# Smartshort: 1
# Indexification: 1
# Endnote: 1
# Reza: 1
# Talukder: 1
# Semrushgrammerly: 1
# Aida: 1
# Aje: 1
# Yrs: 1
# Masha: 1
# VidiqSemrushChatGPT: 1
# Kivaby: 1
# MashAllah: 1
# MashaAllah: 1
# Boost: 1
# Sayem: 1
# Ahmed: 1
# Invidio: 1
# Reselling: 1
# Ager: 1
# Chtgpt: 1
# Next: 1
# Xtrem: 1
# Cracked: 1
# Panel: 1
# Na: 1
# Bangla: 1
# Invideostudio: 1
# Nita: 1
# Pictoryai: 1
# Activity: 1
# Navigator: 1
# SEMush: 1
# Keo: 1
# Nicen: 1
# Agula: 1
# Nuaim: 1
# Business: 1
# As: 1
# Abdul: 1
# Khaleque: 1
# Money: 1
# Writersonic: 1
# Kiser: 1
# QuillBot: 1
# Surfshark: 1
# Playht: 1
# Spy: 1
# Rank: 1
# Math: 1
# Yoast: 1
# Gramarly: 1
# Ryd: 1
# Murf: 1
# EMrsh: 1
# Revealer: 1
# Bonus: 1
# Article: 1
# Blog: 1
# Account: 1
# Bhaijan: 1
# Monther: 1
# Ekhane: 1
# Ekhon: 1
# Ptice: 1
# Mayad: 1
# Lovely: 1
# Lifelife: 1
# Have: 1
# Aherfs: 1
# Kebol: 1
# Apnra: 1
# Shop: 1
# PLUS: 1
# Power: 1
# Esob: 1
# Fast: 1
# Suppprt: 1
# ChatGPT40: 1
# Logo: 1
# Another: 1
# Todays: 1
# Biswass: 1
# HIX: 1
# Mohashin: 1
# Hossen: 1
# Smodin: 1
# Hsref: 1
# Nitay: 1
# Bistarito: 1
# Picfinder: 1
# Hoilay: 1
# Jon: 1
# Reaction: 1
# Review: 1
# Olny: 1
# Atto: 1
# Seowriter: 1
# Aiseo: 1
# Use: 1
# Korle: 1
# Abar: 1
# Renew: 1
# Quality: 1
# Trust: 1
# Oroni: 1
# SEOtimer: 1
# Smodinio: 1
# Semruah: 1
# Egulo: 1
# Generation: 1
# Tool: 1
# SEObility: 1
# Nibo: 1
# Customer: 1
# RankMath: 1
# Yost: 1
# Mrush: 1
# GravityWrite: 1
# Animation: 1
# Ho: 1
# Nur: 1
# Alom: 1
# Usaid: 1
# Hudair: 1
# Original: 1
# Shodo: 1
# PriCe: 1
# Why: 1
# Kotodiner: 1
# Github: 1
# LSI: 1
# Themeforest: 1
# Codecanyon: 1
# Cart: 1
# Mymuna: 1
# Akter: 1
# Semrash: 1
# Jesper: 1
# Wp: 1
# Long: 1
# Io: 1
# Shudu: 1
# Jekono: 1
# Naki: 1
# Wellsaidlabscom: 1
# Helloapnader: 1
# Gigapixel: 1
# Word: 1
# SH: 1
# Sajal: 1
# Sckripp: 1
# Icca: 1
# Semrushjaspergrammarly: 1
# Eita: 1
# Samira: 1
# Sultana: 1
# Pdf: 1
# Borhan: 1
# Sakib: 1
# Onek: 1
# Affpilot: 1
# Nichescraper: 1
# Setapp: 1
# Agency: 1
# Eki: 1
# Learning: 1
# Vaia: 1
# Graphics: 1
# Authentic: 1
# Mj: 1
# Koyjon: 1
# Po: 1
# Kno: 1
# Closercopy: 1
# Prise: 1
# Smresh: 1
# Surferseo: 1
# Nity: 1
# Sumrush: 1
# Samruch: 1
# Pricw: 1
# Singular: 1
# Semsush: 1
# Aisob: 1
# Nia: 1
# Camtasia: 1
# Khoto: 1
# VIDQ: 1
# Pric: 1
# Hmm: 1
# Tube: 1
# Khoroch: 1
# Vidiiq: 1
# Kibhabe: 1
# Baharul: 1
# Mahadi: 1
# Ashrefsgroupbuy: 1
# Soon: 1
# Credit: 1
# Koita: 1
# KORE: 1
# Zihad: 1
# Hossan: 1
# Tell: 1
# Mashallah: 1
# Ahtefs: 1
# Aeirokom: 1
# Sobgula: 1
# Ahrefhs: 1
# Sesta: 1
# Sadek: 1
# Mia: 1
# Kemon: 1
# Updated: 1
# Envatoelements: 1
# Pz: 1
# Magic: 1
# Enveto: 1
# Iam: 1
# Aksathe: 1
# Mollah: 1
# Shahin: 1
# Dear: 1
# Users: 1
# Drop: 1
# Hurry: 1
# Kling: 1
# Leanadro: 1
# Ideogramcom: 1
# Open: 1
# Lab: 1
# Midjurny: 1
# Saddam: 1
# Hossain: 1
# Mehedi: 1
# Idiogram: 1
# Kreadoai: 1
# Midjurney: 1
# Faiaz: 1
# More: 1
# Lagbo: 1
# Johir: 1
# Rayhan: 1
# Sob: 1
# Tha: 1
# Shopx100: 1
# Folow: 1
# Take: 1
# No: 1
# Koi: 1
# Kub: 1
# Social: 1
# Nondrop: 1
# Page: 1
# Follower: 1
# Omar: 1
# Sadi: 1
# Mst: 1
# Sadiya: 1
# Khatun: 1
# Upgrade: 1
# WhatsApp: 1
# Freelancer: 1
# Music: 1
# Pass: 1
# Rafiul: 1
# Prodhann: 1
# Rafi: 1
# Islamm: 1
# Looking: 1
# Youre: 1
# Ordar: 1
# Fivarr: 1
# Fasebook: 1
# Learn: 1
# Studio: 1
# Learondo: 1
# TV: 1
# Zee5: 1
# Dualingo: 1
# Early: 1
# FUBU: 1
# Eyecon: 1
# Camscanner: 1
# Update: 1
# DemoCreator: 1
# Appreciate: 1
# Bought: 1
# MS: 1
# Unader: 1
# You: 1
# Din: 1
# Shurfshark: 1
# Koresi: 1
# Hoyese: 1
# Pabo: 1
# Nilam: 1
# Well: 1
# Deal: 1
# Niyechi: 1
# Vlo: 1
# Helum: 1
# Etc: 1
# Twitter: 1
# Reviews: 1
# Sutterstock: 1
# Elevenlab: 1
# Invato: 1
# Onestream: 1
# VideoExpress: 1
# Heyden: 1
# Hlw: 1
# Gf: 1
# Coocki: 1
# Audible: 1
# Resell: 1
# Pure: 1
# Laravel: 1
# Uber: 1
# Executives: 1
# Properties: 1
# Reservation: 1
# Points: 1
# Agr: 1
# Ashraf: 1
# Mohammed: 1
# Aoun: 1
# Yaser: 1
# Videoscibe: 1
# Studnt: 1
# Waris: 1
# Mukhtar: 1
# Hamid: 1
# Akbar: 1
# Shahroze: 1
# Trustedhighly: 1
# Evanto: 1
# Afzal: 1
# Tariq: 1
# Mention: 1
# Kreepa: 1
# Badar: 1
# Suddozai: 1
# Younib: 1
# Raza: 1
# Surgegraphai: 1
# Haroon: 1
# Gohar: 1
# Animaker: 1
# Hy: 1
# Dm: 1
# Hafiz: 1
# Sahabs: 1
# Stealthwrite: 1
# BypassGPT: 1
# Kime: 1
# Inshot: 1
# BOOK: 1
# BOLT: 1
# Puppetry: 1
# Iphone: 1
# Hojayega: 1
# ShutterStock: 1
# Needed: 1
# Nimra: 1
# Blogging: 1
# Required: 1
# Kise: 1
# Detail: 1
# NAHI: 1
# Hlo: 1
# Plese: 1
# Stealthgpt: 1
# Artlist: 1
# Koy: 1
# Mega: 1
# Eigula: 1
# Enovato: 1
# NeuroWriter: 1
# Majicstic: 1
# Grammrly: 1
# Quitext: 1
# Refer: 1
# Income: 1
# Grammarlymozsemrush: 1
# Grahics: 1
# Vediq: 1
# OriginalityAi: 1
# Seeartai: 1
# Apnarao: 1
# LeonardoAi: 1
# Unsplash: 1
# Flikiai: 1
# Analyze: 1
# Ahrafs: 1
# Erank: 1
# Real: 1
# Keep: 1
# Wonderful: 1
# Its: 1
# Helpful: 1
# Semras: 1
# Mangles: 1
# UberSuggest: 1
# Orsadaron: 1
# Wondershare: 1
# Marchant: 1
# Informer: 1
# Manychat: 1
# There: 1
# Assa: 1
# Gravitywriter: 1
# Toos: 1
# Aiseoai: 1
# VIDIQ: 1
# Phone: 1
# Method: 1
# Course: 1
# Source: 1
# Export: 1
# ChaGpt: 1
# Fixed: 1
# Kitpapacom: 1
# GPt: 1
# Derails: 1
# Kittl: 1
# Taka: 1
# Continue: 1
# Per: 1
# Ahaduzzaman: 1
# Tubebuddy: 1
# Koalash: 1
# Quetext: 1
# Love: 1
# Pricee: 1
# Saiful: 1
# Kayword: 1
# Ahrep: 1
# Smrush: 1
# VidQ: 1
# Clint: 1
# Asifur: 1
# Rahman: 1
# ImAm: 1
# HaSan: 1
# Project: 1
# Customized: 1
# Element: 1
# Dfqdl: 1
# Pol: 1
# InterestedHow: 1
# Site: 1
# Audit: 1
# Neutonwriter: 1
# Serfer: 1
# Janaben: 1
# Duplichecker: 1
# Stock: 1
# Intersted: 1
# Jenni: 1
# InterestedI: 1
# CanvaJesperahrefs: 1
# Internet: 1
# SEMrushAhrefsYoast: 1
# Always: 1
# Akhan: 1
# HAVE: 1
# GOT: 1
# TOOLS: 1
# INSTANTLY: 1
# AND: 1
# THEIR: 1
# SERVICES: 1
# ARE: 1
# QUITE: 1
# EXTRAORDINARY: 1
# WILL: 1
# GET: 1
# SERVICE: 1
# FASTER: 1
# THANKS: 1
# Grab: 1
# FaisalitebToolscom: 1
# VidLQ: 1
# Provide: 1
# Education: 1
# Canvapropremiumforsalebd: 1
# Zikanalytics: 1
# Merch: 1
# Possible: 1
# Chorki: 1
# Traffic: 1
# Chatgbt: 1
# Which: 1
# Plagiarism: 1
# Neuronwriter: 1
# Rate: 1
# Praise: 1
# Singel: 1
# Ektu: 1
# Cha: 1
# Vuya: 1
# Midjounry: 1
# Sobguly: 1
# NEED: 1

# %%
comment_data.head()
# Out:
#                   Author                             Content  \
# 0      Md Minhajul Islam
# 1  Kazi Siratul Mostakim  Brilliant learning app share price
# 2             Nehal Anas             Lightroom premium price
# 3    Rahmot Hossain Niaz       vi envato elements price koto
# 4           Rehdoy Hasan          wellsaid labs Ai Voice lab
#
#    SubCommentsCount           CommentAt  DayOfWeek  Hour  WordCount
# 0               1.0 2024-06-05 14:52:02  Wednesday  14.0          1
# 1               0.0 2024-06-06 19:39:45   Thursday  19.0          5
# 2               1.0 2024-06-09 18:40:53     Sunday  18.0          3
# 3               1.0 2024-06-10 09:53:42     Monday   9.0          5
# 4               2.0 2024-06-10 10:03:43     Monday  10.0          5

# %%
import re
from collections import Counter
import matplotlib.pyplot as plt

# List of tools/software names provided by the user
tools_list = [
    "Sermush Unlimited", "Ubersuggest", "Moz pro", "Grammarly", "Chatgpt plus",
    "Sincodeai", "Leonardo.ai", "Midjourney", "Bypassgpt", "Stealth Writer",
    "Writehuman.ai", "Originality Ai", "Frase.Io", "Neuronwriter", "Answerthepublic",
    "Labrika", "wordtune", "Revoicer", "Imgupscaler", "Screpy", "Mangools",
    "Seocrawl", "Linguix", "Nichesss", "Closercopy", "Copymatics", "Ocoya ai",
    "Writerzen", "Renderforest", "Placeit", "Powtoon", "Vyond", "Helium10", "Flaticon",
    "Freepik Premium", "Canva Pro", "Vecteezy", "Icons8", "Similarweb", "Tome App",
    "Uizard.io", "Airbrush", "Pngtree", "Ai Video Creator", "Flexclip", "Sketch Geniusapp",
    "Steve.ai", "Creative Fabrica", "Spamzilla", "Udemy Premium", "Linkedin Learning",
    "Coursera Plus", "Masterclass", "Codeacademy", "Skillshare", "Scribd", "Epidemic Sound",
    "Keyword Revelar", "Pixlr", "Piktochart", "Ispionage", "Article Forge", "Niche Scrapper",
    "Primevideo", "Netflix", "Seobility", "Seositecheckup", "Seoptimer", "Seoscout", "Storybase",
    "Bookbolt", "Merchinformer", "Viral Launch", "Sellthetrend", "Prettymerch", "Zonguru",
    "Smartscout", "Whatsmyserp", "Salesamurai.io", "Tube Ranker", "Creaitor.ai", "Turnitin (Plagiarism)",
    "Craftly Ai", "Jenni Ai", "Localio.ai", "Rytr.me", "Copy Ai", "Jasper Ai", "Quillbot",
    "Quetext", "Keywordtool.io", "Spyfu", "Buzzsumo", "Deepl Pro", "Article Builder", "Hashtagsforlikes",
    "Woorank", "Indexification", "Junglescout", "Buzzstream", "Picmonkey", "Fotojet", "Vista",
    "Writersonic", "Serpstat", "Unbounce", "Designbeast", "Picsart", "Ai Image", "Snackeet",
    "Dream.ai", "Grothbarseo", "Designs.ai", "Doodly", "Toonly", "Toons.ai", "Invideo", "Vidiq Pro",
    "Lovo.ai", "Topicmojo", "Play.ht", "Videoscribe", "Robinize Ai", "Peppercontent.io", "Crazyegg",
    "Brand Overflow", "B2b Leadgen", "Hoichoi.tv", "Chorki", "Ipvanish Premium", "Storyblocks",
    "Envato Elements", "Motion Arry", "Wordhero", "Katteb ai", "Writeseed", "Writecream",
    "Plugintheme.net", "Gplrock", "Lovepik", "Pikbest", "Backlink Repository", "Spinrewriter",
    "Iconscout", "Lumen5", "Nando.ai", "Ai Seo", "Word.ai", "Adspy", "500px Downloader",
    "Alamy Downloader", "Eyeem Downloader", "Favepng Downloader", "Artlist Downloader",
    "Shutterstock Downloader", "Ai Image Generator", "Istock Downloader", "Ninja Seo Tools",
    "Ninja Web Tools", "Domain Search Tools", "Storyblocks Downloader", "Adobe Downloader",
    "Ecomhunt", "Spoke.app", "Smodin_io", "Creatopy", "Hellowscribe", "Rezi.Ai", "Prezi.Ai",
    "Figma", "Visme", "Scite ai", "GPTZero", "1of10.com", "Podcastle.ai", "Loom", "Prowritingaid",
    "Perplexity.ai", "Gnuelements", "lex.page", "123rf", "Cramly", "Writefull", "Fomoclips",
    "Chatpdf", "Vidtoons", "Smodin io", "sobgula", "semrush"
]

# Convert the tools list to a set for efficient matching
tools_set = set(tools_list)

# Extract relevant comments content
comments_content = comment_data['Content'].astype(str).str.lower()

# Count occurrences of tools/software in the comments
tool_count = Counter()
for comment in comments_content:
    for tool in tools_set:
        if tool.lower() in comment:
            tool_count[tool] += 1

# Convert counts to a DataFrame for plotting
tool_count_df = pd.DataFrame(tool_count.items(), columns=['Tool', 'Count']).sort_values(by='Count', ascending=False)

# Plot the top 20 most mentioned tools
top_tools = tool_count_df.head(20)
plt.figure(figsize=(12, 8))
plt.barh(top_tools['Tool'], top_tools['Count'], color='skyblue')
plt.xlabel('Mention Count')
plt.ylabel('Tools/Software')
plt.title('Top 20 Mentioned Tools/Software in Comments')
plt.gca().invert_yaxis()  # To display the highest count at the top
plt.show()

# Output the top tools for further inspection
tool_count_df.head(20)
# Out:
#                Tool  Count
# 6           semrush    336
# 12       Midjourney     49
# 13          Invideo     40
# 9         Canva Pro     39
# 1         Grammarly     30
# 0   Envato Elements     15
# 18          Netflix     13
# 29      Ubersuggest     12
# 26        Jasper Ai     11
# 5      Chatgpt plus     10
# 11         Quillbot     10
# 30          Quetext      7
# 27          Moz pro      7
# 8       Videoscribe      6
# 10          Picsart      5
# 2            Scribd      4
# 16            Figma      4
# 23            Vyond      4
# 39         Vecteezy      3
# 17   Indexification      3

# %%
# Plot the remaining tools not included in the top 20
remaining_tools = tool_count_df.iloc[20:]

# Plotting all remaining tools as a bar chart
plt.figure(figsize=(12, 50))  # Adjust height for large datasets
plt.barh(remaining_tools['Tool'], remaining_tools['Count'], color='lightgreen')
plt.xlabel('Mention Count')
plt.ylabel('Tools/Software')
plt.title('Remaining Mentioned Tools/Software in Comments')
plt.gca().invert_yaxis()  # To display the highest count at the top
plt.tight_layout()
plt.show()

# Output remaining tools as a Python list
remaining_tools_list = remaining_tools.to_dict(orient='records')
remaining_tools_list
# Out:
# [{'Tool': 'Coursera Plus', 'Count': 3},
#  {'Tool': 'Powtoon', 'Count': 2},
#  {'Tool': 'Chorki', 'Count': 2},
#  {'Tool': 'Storyblocks', 'Count': 2},
#  {'Tool': 'wordtune', 'Count': 2},
#  {'Tool': 'Stealth Writer', 'Count': 2},
#  {'Tool': 'Udemy Premium', 'Count': 2},
#  {'Tool': 'Renderforest', 'Count': 2},
#  {'Tool': 'Buzzsumo', 'Count': 2},
#  {'Tool': 'Epidemic Sound', 'Count': 2},
#  {'Tool': 'Placeit', 'Count': 2},
#  {'Tool': 'Bypassgpt', 'Count': 1},
#  {'Tool': 'Bookbolt', 'Count': 1},
#  {'Tool': 'Jenni Ai', 'Count': 1},
#  {'Tool': 'Loom', 'Count': 1},
#  {'Tool': 'Article Builder', 'Count': 1},
#  {'Tool': 'sobgula', 'Count': 1},
#  {'Tool': 'Closercopy', 'Count': 1},
#  {'Tool': 'Linkedin Learning', 'Count': 1},
#  {'Tool': 'Seobility', 'Count': 1},
#  {'Tool': 'Vidiq Pro', 'Count': 1},
#  {'Tool': 'Writersonic', 'Count': 1},
#  {'Tool': 'Skillshare', 'Count': 1},
#  {'Tool': 'Neuronwriter', 'Count': 1}]

# %%
# Ensure 'CommentAt' is in datetime format
comment_data['CommentAt'] = pd.to_datetime(comment['CommentAt'])
price_comments = comment[comment['Content'].str.contains('price', case=False, na=False)]
price_comments['AM_PM'] = price_comments['CommentAt'].dt.strftime('%p')
am_pm_counts = price_comments['AM_PM'].value_counts()
print(am_pm_counts)

am_pm_counts.plot(kind='bar', color=['orange', 'blue'])
plt.title('Frequency of Price Comments by AM/PM')
plt.xlabel('Time Period')
plt.ylabel('Number of Comments')
plt.xticks(rotation=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-b96334b7f40f> in <cell line: 2>()
#       1 # Ensure 'CommentAt' is in datetime format
# ----> 2 comment['CommentAt'] = pd.to_datetime(comment['CommentAt'])
#       3 price_comments = comment[comment['Content'].str.contains('price', case=False, na=False)]
#       4 price_comments['AM_PM'] = price_comments['CommentAt'].dt.strftime('%p')
#       5 am_pm_counts = price_comments['AM_PM'].value_counts()
#
# TypeError: string indices must be integers

# %%
comment_data['Content'].value_counts().head()

# %%
# Re-importing necessary libraries
import pandas as pd
import re
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
[
    {'Tool': 'Indexification', 'Count': 3},
    {'Tool': 'Chorki', 'Count': 2},
    {'Tool': 'Stealth Writer', 'Count': 2},
    {'Tool': 'Epidemic Sound', 'Count': 2},
    {'Tool': 'Storyblocks', 'Count': 2},
    {'Tool': 'wordtune', 'Count': 2},
    {'Tool': 'Udemy Premium', 'Count': 2},
    {'Tool': 'Renderforest', 'Count': 2},
    {'Tool': 'Placeit', 'Count': 2},
    {'Tool': 'Powtoon', 'Count': 2},
    {'Tool': 'Buzzsumo', 'Count': 2},
    {'Tool': 'Writersonic', 'Count': 1},
    {'Tool': 'Play.ht', 'Count': 1},
    {'Tool': 'Bypassgpt', 'Count': 1},
    {'Tool': 'Bookbolt', 'Count': 1},
    {'Tool': 'Steve.ai', 'Count': 1},
    {'Tool': 'Jenni Ai', 'Count': 1},
    {'Tool': 'Leonardo.ai', 'Count': 1},
    {'Tool': 'Linkedin Learning', 'Count': 1},
    {'Tool': 'Loom', 'Count': 1},
    {'Tool': 'sobgula', 'Count': 1},
    {'Tool': 'Closercopy', 'Count': 1},
    {'Tool': 'Frase.Io', 'Count': 1},
    {'Tool': 'Skillshare', 'Count': 1},
    {'Tool': 'Seobility', 'Count': 1},
    {'Tool': 'Vidiq Pro', 'Count': 1},
    {'Tool': 'Article Builder', 'Count': 1},
    {'Tool': 'Neuronwriter', 'Count': 1}
]
# Out:
# [{'Tool': 'Indexification', 'Count': 3},
#  {'Tool': 'Chorki', 'Count': 2},
#  {'Tool': 'Stealth Writer', 'Count': 2},
#  {'Tool': 'Epidemic Sound', 'Count': 2},
#  {'Tool': 'Storyblocks', 'Count': 2},
#  {'Tool': 'wordtune', 'Count': 2},
#  {'Tool': 'Udemy Premium', 'Count': 2},
#  {'Tool': 'Renderforest', 'Count': 2},
#  {'Tool': 'Placeit', 'Count': 2},
#  {'Tool': 'Powtoon', 'Count': 2},
#  {'Tool': 'Buzzsumo', 'Count': 2},
#  {'Tool': 'Writersonic', 'Count': 1},
#  {'Tool': 'Play.ht', 'Count': 1},
#  {'Tool': 'Bypassgpt', 'Count': 1},
#  {'Tool': 'Bookbolt', 'Count': 1},
#  {'Tool': 'Steve.ai', 'Count': 1},
#  {'Tool': 'Jenni Ai', 'Count': 1},
#  {'Tool': 'Leonardo.ai', 'Count': 1},
#  {'Tool': 'Linkedin Learning', 'Count': 1},
#  {'Tool': 'Loom', 'Count': 1},
#  {'Tool': 'sobgula', 'Count': 1},
#  {'Tool': 'Closercopy', 'Count': 1},
#  {'Tool': 'Frase.Io', 'Count': 1},
#  {'Tool': 'Skillshare', 'Count': 1},
#  {'Tool': 'Seobility', 'Count': 1},
#  {'Tool': 'Vidiq Pro', 'Count': 1},
#  {'Tool': 'Article Builder', 'Count': 1},
#  {'Tool': 'Neuronwriter', 'Count': 1}]

# %%
# Re-importing necessary libraries
import pandas as pd
import re
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Extracting comments for analysis
data = comment_data # Reassign data to the DataFrame
comments = data['Content'].dropna().astype(str)

# Text cleaning function
def clean_text(text):
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = text.lower()  # Convert to lowercase
    return text

# Clean the comments
cleaned_comments = comments.apply(clean_text)

# Vectorize the text to count word frequencies
vectorizer = CountVectorizer(stop_words='english', max_features=150)
word_counts = vectorizer.fit_transform(cleaned_comments)
word_frequencies = dict(zip(vectorizer.get_feature_names_out(), word_counts.sum(axis=0).A1))

# Generate a word cloud to visualize the most frequent words
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequencies)

# Plot the word cloud
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Frequent Words in Comments')
plt.show()

# Display top words with frequencies for further analysis
sorted_word_frequencies = sorted(word_frequencies.items(), key=lambda x: x[1], reverse=True)
sorted_word_frequencies[:20]  # Top 20 words and their frequencies
# Out:
# [('price', 1264),
#  ('koto', 637),
#  ('semrush', 323),
#  ('ki', 168),
#  ('service', 161),
#  ('tools', 148),
#  ('ai', 147),
#  ('chatgpt', 110),
#  ('pro', 97),
#  ('canva', 92),
#  ('need', 92),
#  ('ase', 90),
#  ('hobe', 83),
#  ('available', 79),
#  ('details', 76),
#  ('ahrefs', 75),
#  ('gpt', 75),
#  ('ache', 74),
#  ('er', 72),
#  ('vai', 72)]

# %%
# Filter tool names and their counts from comments
tools = [
    "Sermush Unlimited", "Ubersuggest", "Moz pro", "Grammarly", "Chatgpt plus",
    "Sincodeai", "Leonardo.ai", "Midjourney", "Bypassgpt", "Stealth Writer",
    "Writehuman.ai", "Originality Ai", "Frase.Io", "Neuronwriter", "Answerthepublic",
    "Labrika", "wordtune", "Revoicer", "Imgupscaler", "Screpy", "Mangools",
    "Seocrawl", "Linguix", "Nichesss", "Closercopy", "Copymatics", "Ocoya ai",
    "Writerzen", "Renderforest", "Placeit", "Powtoon", "Vyond", "Helium10", "Flaticon",
    "Freepik Premium", "Canva Pro", "Vecteezy", "Icons8", "Similarweb", "Tome App",
    "Uizard.io", "Airbrush", "Pngtree", "Ai Video Creator", "Flexclip", "Sketch Geniusapp",
    "Steve.ai", "Creative Fabrica", "Spamzilla", "Udemy Premium", "Linkedin Learning",
    "Coursera Plus", "Masterclass", "Codeacademy", "Skillshare", "Scribd", "Epidemic Sound",
    "Keyword Revelar", "Pixlr", "Piktochart", "Ispionage", "Article Forge", "Niche Scrapper",
    "Primevideo", "Netflix", "Seobility", "Seositecheckup", "Seoptimer", "Seoscout", "Storybase",
    "Bookbolt", "Merchinformer", "Viral Launch", "Sellthetrend", "Prettymerch", "Zonguru",
    "Smartscout", "Whatsmyserp", "Salesamurai.io", "Tube Ranker", "Creaitor.ai", "Turnitin (Plagiarism)",
    "Craftly Ai", "Jenni Ai", "Localio.ai", "Rytr.me", "Copy Ai", "Jasper Ai", "Quillbot",
    "Quetext", "Keywordtool.io", "Spyfu", "Buzzsumo", "Deepl Pro", "Article Builder", "Hashtagsforlikes",
    "Woorank", "Indexification", "Junglescout", "Buzzstream", "Picmonkey", "Fotojet", "Vista",
    "Writersonic", "Serpstat", "Unbounce", "Designbeast", "Picsart", "Ai Image", "Snackeet",
    "Dream.ai", "Grothbarseo", "Designs.ai", "Doodly", "Toonly", "Toons.ai", "Invideo", "Vidiq Pro",
    "Lovo.ai", "Topicmojo", "Play.ht", "Videoscribe", "Robinize Ai", "Peppercontent.io", "Crazyegg",
    "Brand Overflow", "B2b Leadgen", "Hoichoi.tv", "Chorki", "Ipvanish Premium", "Storyblocks",
    "Envato Elements", "Motion Arry", "Wordhero", "Katteb ai", "Writeseed", "Writecream",
    "Plugintheme.net", "Gplrock", "Lovepik", "Pikbest", "Backlink Repository", "Spinrewriter",
    "Iconscout", "Lumen5", "Nando.ai", "Ai Seo", "Word.ai", "Adspy", "500px Downloader",
    "Alamy Downloader", "Eyeem Downloader", "Favepng Downloader", "Artlist Downloader",
    "Shutterstock Downloader", "Ai Image Generator", "Istock Downloader", "Ninja Seo Tools",
    "Ninja Web Tools", "Domain Search Tools", "Storyblocks Downloader", "Adobe Downloader",
    "Ecomhunt", "Spoke.app", "Smodin_io", "Creatopy", "Hellowscribe", "Rezi.Ai", "Prezi.Ai",
    "Figma", "Visme", "Scite ai", "GPTZero", "1of10.com", "Podcastle.ai", "Loom", "Prowritingaid",
    "Perplexity.ai", "Gnuelements", "lex.page", "123rf", "Cramly", "Writefull", "Fomoclips",
    "Chatpdf", "Vidtoons", "Smodin io", "sobgula", "semrush"
]

# Count mentions of each tool in the cleaned comments
tool_mentions = {tool: sum(cleaned_comments.str.contains(tool, case=False)) for tool in tools}

# Convert to a DataFrame for better visualization and sorting
tool_mentions_df = pd.DataFrame(list(tool_mentions.items()), columns=["Tool", "Count"])
tool_mentions_df = tool_mentions_df.sort_values(by="Count", ascending=False)

# Display the tool mentions sorted by count
print(tool_mentions_df.head(10), tool_mentions_df)
# Out:
# <ipython-input-43-b0d429c33f27>:37: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   tool_mentions = {tool: sum(cleaned_comments.str.contains(tool, case=False)) for tool in tools}
#                 Tool  Count
# 188          semrush    336
# 7         Midjourney     49
# 116          Invideo     40
# 35         Canva Pro     39
# 3          Grammarly     30
# 6        Leonardo.ai     16
# 131  Envato Elements     15
# 64           Netflix     13
# 1        Ubersuggest     12
# 87         Jasper Ai     11                   Tool  Count
# 188            semrush    336
# 7           Midjourney     49
# 116            Invideo     40
# 35           Canva Pro     39
# 3            Grammarly     30
# ..                 ...    ...
# 93           Deepl Pro      0
# 22             Linguix      0
# 95    Hashtagsforlikes      0
# 96             Woorank      0
# 0    Sermush Unlimited      0
#
# [189 rows x 2 columns]
